# %%
import matplotlib.pyplot as plt
import open3d as o3d
import pandas as pd
import numpy as np
import cv2

# %%
import os
import glob
import pathlib

# %%
import sys
sys.path.append('/media/julien/Data/pro/Dev/HD_Radar/HD_Radar_Processing_Library/rpl_cython')
from RPL_WRAPPER import RPL_wrapper

### initialize library ####
hamming_win = '/media/julien/Data/pro/Dev/HD_Radar/parameters/WindowStaircaseSilverFeb20.bin'
calib_real = '/media/julien/Data/pro/Dev/HD_Radar/parameters/Tx_Rx_real_3D.bin'
calib_imag = '/media/julien/Data/pro/Dev/HD_Radar/parameters/Tx_Rx_imag_3D.bin'

rad = RPL_wrapper(calib_real.encode(),calib_imag.encode(),hamming_win.encode())

numChips            = 4
numRxPerChip        = 4
numRx               = (numChips*numRxPerChip)
numSamplePerChirp   = 512
numChirps           = 256
RawFrameSize        = (numSamplePerChirp*numChirps*numRxPerChip*2)
   
size_max = 10000

azimuth = np.zeros(size_max,dtype = np.float32)
elevation = np.zeros(size_max,dtype = np.float32)
power = np.zeros(size_max,dtype = np.float32)
doppler = np.zeros(size_max,dtype = np.float32)
x = np.zeros(size_max,dtype = np.float32)
y = np.zeros(size_max,dtype = np.float32)
z = np.zeros(size_max,dtype = np.float32)
v = np.zeros(size_max,dtype = np.float32)
r = np.zeros(size_max,dtype = np.float32)

# %%
# Import DBReader
sys.path.append('/media/julien/Data/pro/Dev/HD_Radar/HDRadar_dataset/DBReader')
from DBReader.DBReader import SyncReader,ASyncReader
from DBReader.SensorsReaders import CANDecoder

# %%
offset_radar = -180000
offset_scala = -40000

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, models, transforms

sys.path.insert(0,'/media/julien/Data/pro/Dev/HD_Radar/2D_detection/pytorch-retinanet')

from retinanet.dataloader import CocoDataset, CSVDataset, CityscapesDataset,collater
from retinanet.dataloader import Resizer, AspectRatioBasedSampler, Augmenter, UnNormalizer, Normalizer

retinanet = torch.load('/media/julien/Data/pro/Dev/HD_Radar/2D_detection/pytorch-retinanet/SecondRun/retinanet_45.pt')
retinanet = retinanet.cuda()
retinanet.eval()
transform=transforms.ToTensor()

# %%
from scipy.spatial.transform import Rotation as R
def rotation3d(x,y,z,roll,yaw,pitch):
    
    pitch = np.radians(pitch)
    yaw = np.radians(yaw)
    roll = np.radians(roll)
    
    xyz = np.stack([x,y,z],axis=1)
    
    rotation_vector = np.array([roll,pitch,yaw])
    rotation = R.from_rotvec(rotation_vector)
    rotated_vec = rotation.apply(xyz)
    
    return rotated_vec[:,0],rotated_vec[:,1],rotated_vec[:,2]


#    float x,y,z;
#    float intensity;
#    float radialDistance;
#    float polAngle,aziAngle;
#    uint8_t layer_index;

def ApplyCalib(pcl,index,yaw):
    
    if(index%2):
        offset = -.50/180*3.14
    else:
        offset = +.10/180*3.14
    
    offset+=0.5/180*3.14
    
    x = pcl[:,4] * np.cos(pcl[:,5]+offset) * np.cos(pcl[:,6]+yaw)
    y = pcl[:,4] * np.cos(pcl[:,5]+offset) * np.sin(pcl[:,6]+yaw)
    z = pcl[:,4] * np.sin(pcl[:,5]+offset) + 0.37#0.42
    
    pcl[:,0] = x
    pcl[:,1] = y
    pcl[:,2] = z
    
    return pcl

# %%
from sklearn.linear_model import RANSACRegressor
from sklearn.datasets import make_regression
from sklearn import linear_model

def remove_ground(xyz):
    
    id = np.where( (xyz[:,1]>-5) &  (xyz[:,1]<5) & (xyz[:,0]<15)& (xyz[:,0]>2))[0]
    X = xyz[id,0].reshape((-1, 1))
    y = xyz[id,2]
    lr = linear_model.RANSACRegressor()
    lr.fit(X,y)
    id = np.where( (xyz[:,2] > 0.1+(xyz[:,0] * lr.estimator_.coef_[0])) | (xyz[:,0]>20) )[0]
    
    return xyz[id,:]

# %%
root_dir = '/media/julien/HD_RADAR/FinalDataset/Pitch0Deg/RECORD@2020-11-22_12.49.00'
root_dir = '/media/julien/HD_RADAR/FinalDataset/Pitch2Deg/RECORD@2020-11-12_13.08.59'
#root_dir = '/media/julien/HD_RADAR/FinalDataset/Pitch0Deg/RECORD@2020-11-22_12.54.38'
root_dir = '/media/julien/HD_RADAR/FinalDataset/Pitch2Deg/RECORD@2020-11-12_12.56.12'
db = SyncReader(root_dir,tolerance=20000,offset_radar=offset_radar,offset_scala=offset_scala)
# Out:
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     can
# -     radar_ch3
# -     camera
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  20.767778477029577 %
# Total corrupted frames:  1.825047199496539 %

# %%
root_folder = '/media/julien/HD_RADAR/FinalDataset/Pitch0Deg'
count=0
for f in os.listdir(root_folder):
    path_dataset = os.path.join(root_folder,f)
    db = SyncReader(path_dataset,tolerance=20000,offset_radar=offset_radar,offset_scala=offset_scala,silent=False)


    for jj in range(len(db)-2):
        data = db.GetSensorData(jj)
        
        img = data['camera']['data'].copy().astype(np.float32)/255.0
        img2 = cv2.resize(img,dsize=(960,544))
        ratioX = img.shape[1]/960
        ratioY = img.shape[0]/544
        img3 = (img2-np.array([[[0.485, 0.456, 0.406]]]))/np.array([[[0.229, 0.224, 0.225]]])
        img3 = transform(img3).unsqueeze(0)
        nms_scores, nms_class, boxes = retinanet(img3.cuda().float())
        boxes = boxes.detach().cpu().numpy()
        boxes[:,0]*=ratioX
        boxes[:,2]*=ratioX
        boxes[:,1]*=ratioY
        boxes[:,3]*=ratioY

        nms_scores = nms_scores.detach().cpu().numpy()
        nms_class = nms_class.detach().cpu().numpy()

        detection_2D=[]
        for s,c,b in zip(nms_scores, nms_class, boxes):
            if(s>0.5 and c==0):
                detection_2D.append(b)

        if(len(detection_2D)==0):
            continue

        rad.process(data['radar_ch3']['data'],data['radar_ch0']['data'],data['radar_ch1']['data'],data['radar_ch2']['data'])

        azimuth = np.zeros(size_max,dtype = np.float32)
        elevation = np.zeros(size_max,dtype = np.float32)
        power = np.zeros(size_max,dtype = np.float32)
        doppler = np.zeros(size_max,dtype = np.float32)
        x = np.zeros(size_max,dtype = np.float32)
        y = np.zeros(size_max,dtype = np.float32)
        z = np.zeros(size_max,dtype = np.float32)
        v = np.zeros(size_max,dtype = np.float32)
        r = np.zeros(size_max,dtype = np.float32)
        NBPts = rad.get_pcl(r,azimuth,elevation,power,doppler, x,y,z,v,size_max)
        x = x[:NBPts]
        y = y[:NBPts]
        doppler = doppler[:NBPts]

        pcl = data['scala']['data'].astype('float32').copy()
        pcl = ApplyCalib(pcl,data['scala']['sample_number'],0)
        pcl = remove_ground(pcl)
        id_pcl = np.where( (pcl[:,0]>2) & (pcl[:,0]<100) & (pcl[:,1]>-40) & (pcl[:,1]<40))[0]
        pcl = pcl[id_pcl]

        objectPoints_radar = np.zeros((len(x),3))
        objectPoints_radar[:,0]=y
        objectPoints_radar[:,1]=x
        objectPoints_radar[:,2]=0.8

        objectPoints_laser = np.zeros((len(pcl),3))
        objectPoints_laser[:,0]=-pcl[:,1]
        objectPoints_laser[:,1]=pcl[:,0]
        objectPoints_laser[:,2]=pcl[:,2]

        imgpts_laser, _ = cv2.projectPoints(objectPoints_laser, rvecs, tvecs, camera_matrix, dist_coeffs)
        imgpts_laser=imgpts_laser.squeeze(1)
        imgpts_laser=imgpts_laser.astype('int')

        imgpts_radar, _ = cv2.projectPoints(objectPoints_radar, rvecs, tvecs, camera_matrix, dist_coeffs)
        imgpts_radar=imgpts_radar.squeeze(1)
        imgpts_radar=imgpts_radar.astype('int')


        id_valid = []
        id_valid_rad = []
        id_valid_laser=[]
        for i,bb in enumerate(detection_2D):
            x1 = bb[0]
            y1 = bb[1]
            x2 = bb[2]
            y2 = bb[3]

            # does it contains radar poinst?
            id_rad = np.where( (imgpts_radar[:,0]>=x1) & (imgpts_radar[:,0]<=x2) & (imgpts_radar[:,1]>=y1) & (imgpts_radar[:,1]<=y2))[0]
            id_laser = np.where( (imgpts_laser[:,0]>=x1) & (imgpts_laser[:,0]<=x2) & (imgpts_laser[:,1]>=y1) & (imgpts_laser[:,1]<=y2))[0]

            if(len(id_rad)>0 and len(id_laser)>0):
                id_valid.append(i)
                id_valid_rad.append(id_rad)
                id_valid_laser.append(id_laser)


        
        if(len(id_valid)>0):
            

            id_valid_rad = np.concatenate(id_valid_rad)
            id_valid_laser = np.concatenate(id_valid_laser)
            image = data['camera']['data'].copy()
            image = cv2.resize(image,dsize=(int(image.shape[1]/2),int(image.shape[0]/2)))
            for i in id_valid:
                bb = detection_2D[i]
                x1 = bb[0]
                y1 = bb[1]
                x2 = bb[2]
                y2 = bb[3]

                image = cv2.rectangle(image, tuple((int(x1/2),int(y1/2))), tuple((int(x2/2),int(y2/2))), (255,0,0),2)

                for pt in imgpts_laser[id_valid_laser]:
                    if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
                        image = cv2.circle(image, tuple((int(pt[0]/2),int(pt[1]/2))), 1, (0,0,255),3)
                        
                for pt in imgpts_radar:
                    if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
                        image = cv2.circle(image, tuple((int(pt[0]/2),int(pt[1]/2))), 1, (0,255,0),3)

            #cv2.imshow('annotation',image)
            #k = cv2.waitKey(0) & 0xFF
            #cv2.destroyAllWindows()

            map = np.ones((540,400,3))*255
            map[500,:,:] = 150
            map[:,200,:] = 150
            map = cv2.line(map, tuple((0,350)), tuple((200,500)),(150,150,150),1)
            map = cv2.line(map, tuple((400,350)), tuple((200,500)),(150,150,150),1)
            
            
            for pt in objectPoints_laser:
                pos_x = 500-int(pt[1]/0.2)
                pos_y = int(pt[0]/0.1)+200
                
                if(pos_x>0 and pos_x<540 and pos_y>0 and pos_y<400):
                    
                    map = cv2.circle(map, tuple((pos_y,pos_x)), 1, (0,0,255),1)
                    
            for pt in objectPoints_laser[id_valid_laser]:
                pos_x = 500-int(pt[1]/0.2)
                pos_y = int(pt[0]/0.1)+200
                
                if(pos_x>0 and pos_x<540 and pos_y>0 and pos_y<400):
                    
                    map = cv2.circle(map, tuple((pos_y,pos_x)), 1, (0,0,0),1)
                    
                    
            for pt in objectPoints_radar:
                pos_x = 500-int(pt[1]/0.2)
                pos_y = int(pt[0]/0.1)+200
                
                if(pos_x>0 and pos_x<540 and pos_y>0 and pos_y<400):
                    
                    map = cv2.circle(map, tuple((pos_y,pos_x)), 1, (0,255,0),1)
                    
            for pt in objectPoints_radar[id_valid_rad]:
                pos_x = 500-int(pt[1]/0.2)
                pos_y = int(pt[0]/0.1)+200
                
                if(pos_x>0 and pos_x<540 and pos_y>0 and pos_y<400):
                    
                    map = cv2.circle(map, tuple((pos_y,pos_x)), 2, (0,0,0),2)
                    
            im2 = np.concatenate([image,map],axis=1)
            image_filename = f+'_{:06}_imageIndex_{:06}.jpg'.format(jj,data['camera']['index'])
            cv2.imwrite(os.path.join('/media/julien/HD_RADAR/FinalDataset/auto_anno_0deg',image_filename),im2)
# Out:
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     can
# -     radar_ch3
# -     camera
# -     radar_ch0
# -     radar_ch2
# -     gps
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  19.696969696969695 %
# Total corrupted frames:  0.0 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  22.123893805309734 %
# Total corrupted frames:  0.0 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     radar_ch0
# -     can
# -     radar_ch2
# -     radar_ch1
# -     radar_ch3
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  27.586206896551722 %
# Total corrupted frames:  3.4482758620689653 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     gps
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  16.554054054054053 %
# Total corrupted frames:  1.3513513513513513 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch3
# -     scala
# -     camera
# -     can
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  54.973821989528794 %
# Total corrupted frames:  5.7591623036649215 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.9523809523809524 %
# Total corrupted frames:  14.285714285714285 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     scala
# -     camera
# -     gps
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  23.519458544839257 %
# Total corrupted frames:  2.5380710659898478 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.9389671361502347 %
# Total corrupted frames:  15.023474178403756 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  39.784946236559136 %
# Total corrupted frames:  84.94623655913979 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     radar_ch2
# -     camera
# -     scala
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  21.777777777777775 %
# Total corrupted frames:  0.4444444444444444 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch0
# -     camera
# -     gps
# -     scala
# -     can
# -     radar_ch2
# -     radar_ch1
# -     radar_ch3
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  20.521172638436482 %
# Total corrupted frames:  2.44299674267101 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     can
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  26.851851851851855 %
# Total corrupted frames:  0.9259259259259258 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     radar_ch3
# -     can
# -     camera
# -     radar_ch0
# -     radar_ch2
# -     gps
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  19.51219512195122 %
# Total corrupted frames:  3.902439024390244 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch2
# -     camera
# -     scala
# -     radar_ch1
# -     radar_ch3
# -     gps
# -     radar_ch0
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.4329004329004329 %
# Total corrupted frames:  2.1645021645021645 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     camera
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  27.659574468085108 %
# Total corrupted frames:  16.312056737588655 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     can
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  15.09433962264151 %
# Total corrupted frames:  2.8301886792452833 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch3
# -     camera
# -     scala
# -     radar_ch0
# -     can
# -     radar_ch2
# -     gps
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  16.666666666666664 %
# Total corrupted frames:  0.4166666666666667 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     camera
# -     radar_ch1
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  25.37313432835821 %
# Total corrupted frames:  10.44776119402985 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  45.14285714285714 %
# Total corrupted frames:  4.0 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch2
# -     scala
# -     camera
# -     can
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  17.073170731707318 %
# Total corrupted frames:  2.4390243902439024 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     radar_ch1
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     gps
# -     radar_ch2
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  13.592233009708737 %
# Total corrupted frames:  1.9417475728155338 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     can
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  85.92592592592592 %
# Total corrupted frames:  2.9629629629629632 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  32.22748815165877 %
# Total corrupted frames:  20.85308056872038 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     can
# -     gps
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  26.55367231638418 %
# Total corrupted frames:  2.2598870056497176 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch1
# -     radar_ch2
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  43.7037037037037 %
# Total corrupted frames:  34.81481481481482 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch1
# -     camera
# -     scala
# -     gps
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.7142857142857143 %
# Total corrupted frames:  13.214285714285715 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     scala
# -     radar_ch2
# -     camera
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  18.591318591318593 %
# Total corrupted frames:  2.538902538902539 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch2
# -     radar_ch1
# -     radar_ch0
# -     radar_ch3
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  9.615384615384617 %
# Total corrupted frames:  1.3736263736263736 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     radar_ch2
# -     can
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  14.489795918367346 %
# Total corrupted frames:  1.2244897959183674 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     camera
# -     scala
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  13.356164383561644 %
# Total corrupted frames:  1.0273972602739725 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  19.81981981981982 %
# Total corrupted frames:  1.8018018018018018 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     can
# -     scala
# -     radar_ch3
# -     gps
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  20.77922077922078 %
# Total corrupted frames:  3.6363636363636362 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  24.601366742596813 %
# Total corrupted frames:  2.050113895216401 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.8333333333333334 %
# Total corrupted frames:  12.916666666666668 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  14.11042944785276 %
# Total corrupted frames:  4.294478527607362 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     radar_ch0
# -     radar_ch2
# -     gps
# -     radar_ch1
# -     radar_ch3
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  4.545454545454546 %
# Total corrupted frames:  72.72727272727273 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  3.488372093023256 %
# Total corrupted frames:  17.441860465116278 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     can
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  22.00557103064067 %
# Total corrupted frames:  0.8356545961002786 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     gps
# -     radar_ch0
# -     camera
# -     scala
# -     radar_ch2
# -     radar_ch1
# -     radar_ch3
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  18.594104308390023 %
# Total corrupted frames:  3.968253968253968 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  15.909090909090908 %
# Total corrupted frames:  1.8181818181818181 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch1
# -     can
# -     scala
# -     camera
# -     gps
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  17.801047120418847 %
# Total corrupted frames:  2.6178010471204187 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     can
# -     scala
# -     radar_ch3
# -     radar_ch2
# -     radar_ch1
# -     gps
# -     radar_ch0
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  22.570532915360502 %
# Total corrupted frames:  6.269592476489027 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  19.35483870967742 %
# Total corrupted frames:  1.2096774193548387 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch0
# -     camera
# -     scala
# -     radar_ch2
# -     radar_ch1
# -     radar_ch3
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.8902077151335311 %
# Total corrupted frames:  25.816023738872403 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch1
# -     scala
# -     can
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  24.848484848484848 %
# Total corrupted frames:  3.6363636363636362 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch3
# -     scala
# -     camera
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.3436426116838488 %
# Total corrupted frames:  11.168384879725087 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     scala
# -     radar_ch3
# -     camera
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  21.664050235478808 %
# Total corrupted frames:  3.6891679748822606 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  23.958333333333336 %
# Total corrupted frames:  1.0416666666666665 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     radar_ch1
# -     camera
# -     scala
# -     gps
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  30.59125964010283 %
# Total corrupted frames:  36.760925449871465 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  26.970954356846473 %
# Total corrupted frames:  3.319502074688797 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     gps
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  17.80185758513932 %
# Total corrupted frames:  2.0123839009287927 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     gps
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  16.0 %
# Total corrupted frames:  1.6551724137931034 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     radar_ch0
# -     scala
# -     can
# -     radar_ch2
# -     radar_ch1
# -     radar_ch3
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  23.832923832923832 %
# Total corrupted frames:  33.415233415233416 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch2
# -     camera
# -     gps
# -     scala
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  1.4285714285714286 %
# Total corrupted frames:  17.61904761904762 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     can
# -     scala
# -     gps
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  21.916010498687662 %
# Total corrupted frames:  27.821522309711288 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     radar_ch2
# -     can
# -     camera
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  24.336283185840706 %
# Total corrupted frames:  1.7699115044247788 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch2
# -     camera
# -     scala
# -     can
# -     radar_ch1
# -     gps
# -     radar_ch3
# -     radar_ch0
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  22.137404580152673 %
# Total corrupted frames:  3.816793893129771 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch3
# -     scala
# -     camera
# -     can
# -     radar_ch0
# -     gps
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  29.212598425196852 %
# Total corrupted frames:  2.9133858267716537 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  13.636363636363635 %
# Total corrupted frames:  1.948051948051948 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     radar_ch2
# -     camera
# -     scala
# -     radar_ch1
# -     gps
# -     radar_ch3
# -     radar_ch0
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  27.014218009478675 %
# Total corrupted frames:  4.265402843601896 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     gps
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  5.0 %
# Total corrupted frames:  35.0 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     can
# -     scala
# -     gps
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  18.97810218978102 %
# Total corrupted frames:  21.41119221411192 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  23.643410852713178 %
# Total corrupted frames:  48.837209302325576 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  23.46938775510204 %
# Total corrupted frames:  1.0204081632653061 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     radar_ch3
# -     can
# -     radar_ch0
# -     gps
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  22.4025974025974 %
# Total corrupted frames:  1.948051948051948 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  19.17808219178082 %
# Total corrupted frames:  2.26027397260274 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     camera
# -     radar_ch3
# -     scala
# -     gps
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  21.551724137931032 %
# Total corrupted frames:  26.436781609195403 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     camera
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  13.071895424836603 %
# Total corrupted frames:  0.6535947712418301 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch1
# -     scala
# -     camera
# -     can
# -     radar_ch0
# -     radar_ch2
# -     gps
# -     radar_ch3
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  18.43003412969283 %
# Total corrupted frames:  0.3412969283276451 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     scala
# -     camera
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  17.132867132867133 %
# Total corrupted frames:  1.048951048951049 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     can
# -     camera
# -     radar_ch3
# -     gps
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  36.702127659574465 %
# Total corrupted frames:  22.340425531914892 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     gps
# -     radar_ch1
# -     radar_ch2
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  10.465116279069768 %
# Total corrupted frames:  69.76744186046511 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     radar_ch3
# -     gps
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  1.5706806282722512 %
# Total corrupted frames:  1.0471204188481675 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     can
# -     radar_ch2
# -     scala
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  19.95798319327731 %
# Total corrupted frames:  3.361344537815126 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.6825938566552902 %
# Total corrupted frames:  17.064846416382252 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  31.06796116504854 %
# Total corrupted frames:  4.854368932038835 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     radar_ch3
# -     gps
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.7194244604316548 %
# Total corrupted frames:  1.9184652278177456 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     can
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     gps
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  26.649746192893403 %
# Total corrupted frames:  0.25380710659898476 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch0
# -     camera
# -     scala
# -     can
# -     radar_ch2
# -     radar_ch1
# -     gps
# -     radar_ch3
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  30.81761006289308 %
# Total corrupted frames:  15.09433962264151 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     radar_ch1
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.8264462809917356 %
# Total corrupted frames:  14.46280991735537 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch2
# -     camera
# -     scala
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.45871559633027525 %
# Total corrupted frames:  16.51376146788991 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     radar_ch3
# -     can
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  34.10852713178294 %
# Total corrupted frames:  49.6124031007752 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     gps
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  11.76470588235294 %
# Total corrupted frames:  23.52941176470588 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     can
# -     gps
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  25.520833333333332 %
# Total corrupted frames:  48.4375 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     gps
# -     can
# -     scala
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  22.815533980582526 %
# Total corrupted frames:  2.912621359223301 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch2
# -     scala
# -     camera
# -     can
# -     radar_ch1
# -     gps
# -     radar_ch3
# -     radar_ch0
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  20.35928143712575 %
# Total corrupted frames:  3.3932135728542914 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     camera
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  10.892857142857142 %
# Total corrupted frames:  1.607142857142857 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     gps
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  22.727272727272727 %
# Total corrupted frames:  0.0 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     radar_ch3
# -     scala
# -     radar_ch0
# -     gps
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.3144654088050315 %
# Total corrupted frames:  2.044025157232704 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     radar_ch1
# -     camera
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.6880733944954129 %
# Total corrupted frames:  1.146788990825688 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  16.046966731898237 %
# Total corrupted frames:  1.761252446183953 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch3
# -     camera
# -     scala
# -     radar_ch0
# -     gps
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  12.290502793296088 %
# Total corrupted frames:  32.960893854748605 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     can
# -     camera
# -     radar_ch3
# -     scala
# -     gps
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  18.314606741573034 %
# Total corrupted frames:  1.1235955056179776 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     can
# -     radar_ch3
# -     gps
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  14.40329218106996 %
# Total corrupted frames:  3.7037037037037033 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     radar_ch0
# -     camera
# -     scala
# -     can
# -     radar_ch2
# -     radar_ch1
# -     radar_ch3
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  23.333333333333332 %
# Total corrupted frames:  0.0 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     scala
# -     camera
# -     radar_ch2
# -     can
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  98.77750611246944 %
# Total corrupted frames:  12.469437652811736 %
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     radar_ch3
# -     radar_ch0
# -     radar_ch2
# -     radar_ch1
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.8438818565400843 %
# Total corrupted frames:  8.860759493670885 %

# %%
##########################  TEST
root_folder = '/media/julien/HD_RADAR/FinalDataset/Pitch2Deg'
f = 'RECORD@2020-11-12_15.53.06'
path_dataset = os.path.join(root_folder,f)

db = SyncReader(path_dataset,tolerance=20000,offset_radar=offset_radar,offset_scala=offset_scala,silent=False)

data = db.GetSensorData(1040)

img = data['camera']['data'].copy().astype(np.float32)/255.0
img2 = cv2.resize(img,dsize=(960,544))
ratioX = img.shape[1]/960
ratioY = img.shape[0]/544
img3 = (img2-np.array([[[0.485, 0.456, 0.406]]]))/np.array([[[0.229, 0.224, 0.225]]])
img3 = transform(img3).unsqueeze(0)
nms_scores, nms_class, boxes = retinanet(img3.cuda().float())
boxes = boxes.detach().cpu().numpy()
boxes[:,0]*=ratioX
boxes[:,2]*=ratioX
boxes[:,1]*=ratioY
boxes[:,3]*=ratioY

nms_scores = nms_scores.detach().cpu().numpy()
nms_class = nms_class.detach().cpu().numpy()

detection_2D=[]
for s,c,b in zip(nms_scores, nms_class, boxes):
    if(s>0.5 and c==0):
        detection_2D.append(b)

rad.process(data['radar_ch3']['data'],data['radar_ch0']['data'],data['radar_ch1']['data'],data['radar_ch2']['data'])

azimuth = np.zeros(size_max,dtype = np.float32)
elevation = np.zeros(size_max,dtype = np.float32)
power = np.zeros(size_max,dtype = np.float32)
doppler = np.zeros(size_max,dtype = np.float32)
x = np.zeros(size_max,dtype = np.float32)
y = np.zeros(size_max,dtype = np.float32)
z = np.zeros(size_max,dtype = np.float32)
v = np.zeros(size_max,dtype = np.float32)
r = np.zeros(size_max,dtype = np.float32)
NBPts = rad.get_pcl(r,azimuth,elevation,power,doppler, x,y,z,v,size_max)
x = x[:NBPts]
y = y[:NBPts]
doppler = doppler[:NBPts]

pcl = data['scala']['data'].astype('float32').copy()
pcl = ApplyCalib(pcl,data['scala']['sample_number'],0)
pcl = remove_ground(pcl)
id_pcl = np.where( (pcl[:,0]>2) & (pcl[:,0]<100) & (pcl[:,1]>-40) & (pcl[:,1]<40))[0]
pcl = pcl[id_pcl]

objectPoints_radar = np.zeros((len(x),3))
objectPoints_radar[:,0]=y
objectPoints_radar[:,1]=x
objectPoints_radar[:,2]=0.8

objectPoints_laser = np.zeros((len(pcl),3))
objectPoints_laser[:,0]=-pcl[:,1]
objectPoints_laser[:,1]=pcl[:,0]
objectPoints_laser[:,2]=pcl[:,2]

imgpts_laser, _ = cv2.projectPoints(objectPoints_laser, rvecs, tvecs, camera_matrix, dist_coeffs)
imgpts_laser=imgpts_laser.squeeze(1)
imgpts_laser=imgpts_laser.astype('int')

imgpts_radar, _ = cv2.projectPoints(objectPoints_radar, rvecs, tvecs, camera_matrix, dist_coeffs)
imgpts_radar=imgpts_radar.squeeze(1)
imgpts_radar=imgpts_radar.astype('int')


id_valid = []
id_valid_rad = []
id_valid_laser=[]
for i,bb in enumerate(detection_2D):
    x1 = bb[0]
    y1 = bb[1]
    x2 = bb[2]
    y2 = bb[3]

    # does it contains radar poinst?
    id_rad = np.where( (imgpts_radar[:,0]>=x1) & (imgpts_radar[:,0]<=x2) & (imgpts_radar[:,1]>=y1) & (imgpts_radar[:,1]<=y2))[0]
    id_laser = np.where( (imgpts_laser[:,0]>=x1) & (imgpts_laser[:,0]<=x2) & (imgpts_laser[:,1]>=y1) & (imgpts_laser[:,1]<=y2))[0]

    if(len(id_rad)>0 and len(id_laser)>0):
        id_valid.append(i)
        id_valid_rad.append(id_rad)
        id_valid_laser.append(id_laser)



if(len(id_valid)>0):


    id_valid_rad = np.concatenate(id_valid_rad)
    id_valid_laser = np.concatenate(id_valid_laser)
    image = data['camera']['data'].copy()
    image = cv2.resize(image,dsize=(int(image.shape[1]/2),int(image.shape[0]/2)))
    for i in id_valid:
        bb = detection_2D[i]
        x1 = bb[0]
        y1 = bb[1]
        x2 = bb[2]
        y2 = bb[3]

        image = cv2.rectangle(image, tuple((int(x1/2),int(y1/2))), tuple((int(x2/2),int(y2/2))), (255,0,0),2)

        for pt in imgpts_laser[id_valid_laser]:
            if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
                image = cv2.circle(image, tuple((int(pt[0]/2),int(pt[1]/2))), 1, (0,0,255),3)

        for pt in imgpts_radar:
            if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
                image = cv2.circle(image, tuple((int(pt[0]/2),int(pt[1]/2))), 1, (0,255,0),3)

    #cv2.imshow('annotation',image)
    #k = cv2.waitKey(0) & 0xFF
    #cv2.destroyAllWindows()

    map = np.ones((540,400,3))*255
    map[500,:,:] = 150
    map[:,200,:] = 150
    map = cv2.line(map, tuple((0,350)), tuple((200,500)),(150,150,150),1)
    map = cv2.line(map, tuple((400,350)), tuple((200,500)),(150,150,150),1)


    for pt in objectPoints_laser:
        pos_x = 500-int(pt[1]/0.2)
        pos_y = int(pt[0]/0.1)+200

        if(pos_x>0 and pos_x<540 and pos_y>0 and pos_y<400):

            map = cv2.circle(map, tuple((pos_y,pos_x)), 1, (0,0,255),1)

    for pt in objectPoints_laser[id_valid_laser]:
        pos_x = 500-int(pt[1]/0.2)
        pos_y = int(pt[0]/0.1)+200

        if(pos_x>0 and pos_x<540 and pos_y>0 and pos_y<400):

            map = cv2.circle(map, tuple((pos_y,pos_x)), 1, (0,0,0),1)


    for pt in objectPoints_radar:
        pos_x = 500-int(pt[1]/0.2)
        pos_y = int(pt[0]/0.1)+200

        if(pos_x>0 and pos_x<540 and pos_y>0 and pos_y<400):

            map = cv2.circle(map, tuple((pos_y,pos_x)), 1, (0,255,0),1)

    for pt in objectPoints_radar[id_valid_rad]:
        pos_x = 500-int(pt[1]/0.2)
        pos_y = int(pt[0]/0.1)+200

        if(pos_x>0 and pos_x<540 and pos_y>0 and pos_y<400):

            map = cv2.circle(map, tuple((pos_y,pos_x)), 2, (0,0,0),2)

    im2 = np.concatenate([image,map],axis=1)

    cv2.imshow('annotation',image)
    k = cv2.waitKey(0) & 0xFF

    cv2.destroyAllWindows()
# Out:
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     scala
# -     can
# -     radar_ch3
# -     radar_ch0
# -     radar_ch1
# -     radar_ch2
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  19.89005497251374 %
# Total corrupted frames:  3.8480759620189904 %

# %%
image2 = data['camera']['data'].copy()
image2.shape
# Out:
# (1080, 1920, 3)

# %%
map = np.zeros((540,280,3))
map.shape
# Out:
# (540, 280, 3)

# %%
img = data['camera']['data'].copy().astype(np.float32)/255.0
img2 = cv2.resize(img,dsize=(960,544))
ratioX = img.shape[1]/960
ratioY = img.shape[0]/544
img3 = (img2-np.array([[[0.485, 0.456, 0.406]]]))/np.array([[[0.229, 0.224, 0.225]]])
img3 = transform(img3).unsqueeze(0)
nms_scores, nms_class, boxes = retinanet(img3.cuda().float())
boxes = boxes.detach().cpu().numpy()
boxes[:,0]*=ratioX
boxes[:,2]*=ratioX
boxes[:,1]*=ratioY
boxes[:,3]*=ratioY

nms_scores = nms_scores.detach().cpu().numpy()
nms_class = nms_class.detach().cpu().numpy()

detection_2D=[]
for s,c,b in zip(nms_scores, nms_class, boxes):
    if(s>0.5 and c==0):
        detection_2D.append(b)
    

rad.process(data['radar_ch3']['data'],data['radar_ch0']['data'],data['radar_ch1']['data'],data['radar_ch2']['data'])

azimuth = np.zeros(size_max,dtype = np.float32)
elevation = np.zeros(size_max,dtype = np.float32)
power = np.zeros(size_max,dtype = np.float32)
doppler = np.zeros(size_max,dtype = np.float32)
x = np.zeros(size_max,dtype = np.float32)
y = np.zeros(size_max,dtype = np.float32)
z = np.zeros(size_max,dtype = np.float32)
v = np.zeros(size_max,dtype = np.float32)
r = np.zeros(size_max,dtype = np.float32)
NBPts = rad.get_pcl(r,azimuth,elevation,power,doppler, x,y,z,v,size_max)
x = x[:NBPts]
y = y[:NBPts]
doppler = doppler[:NBPts]

pcl = data['scala']['data'].astype('float32').copy()
pcl = ApplyCalib(pcl,data['scala']['sample_number'],0)
pcl = remove_ground(pcl)
id_pcl = np.where( (pcl[:,0]>2) & (pcl[:,0]<100) & (pcl[:,1]>-40) & (pcl[:,1]<40))[0]
pcl = pcl[id_pcl]

objectPoints_radar = np.zeros((len(x),3))
objectPoints_radar[:,0]=y
objectPoints_radar[:,1]=x
objectPoints_radar[:,2]=0.8

objectPoints_laser = np.zeros((len(pcl),3))
objectPoints_laser[:,0]=-pcl[:,1]
objectPoints_laser[:,1]=pcl[:,0]
objectPoints_laser[:,2]=pcl[:,2]

imgpts_laser, _ = cv2.projectPoints(objectPoints_laser, rvecs, tvecs, camera_matrix, dist_coeffs)
imgpts_laser=imgpts_laser.squeeze(1)
imgpts_laser=imgpts_laser.astype('int')

imgpts_radar, _ = cv2.projectPoints(objectPoints_radar, rvecs, tvecs, camera_matrix, dist_coeffs)
imgpts_radar=imgpts_radar.squeeze(1)
imgpts_radar=imgpts_radar.astype('int')


id_valid = []
for i,bb in enumerate(detection_2D):
    x1 = bb[0]
    y1 = bb[1]
    x2 = bb[2]
    y2 = bb[3]
    
    # does it contains radar poinst?
    id_rad = np.where( (imgpts_radar[:,0]>=x1) & (imgpts_radar[:,0]<=x2) & (imgpts_radar[:,1]>=y1) & (imgpts_radar[:,1]<=y2))[0]
    id_laser = np.where( (imgpts_laser[:,0]>=x1) & (imgpts_laser[:,0]<=x2) & (imgpts_laser[:,1]>=y1) & (imgpts_laser[:,1]<=y2))[0]
    
    if(len(id_rad)>0 and len(id_laser)>0):
        id_valid.append(i)
        
image = data['camera']['data'].copy()
for i in id_valid:
    bb = detection_2D[i]
    x1 = bb[0]
    y1 = bb[1]
    x2 = bb[2]
    y2 = bb[3]

    image = cv2.rectangle(image, tuple((x1,y1)), tuple((x2,y2)), (0,0,255),3)
    for pt in imgpts_radar[id_rad]:
        if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
            image = cv2.circle(image, tuple(pt), 3, (0,255,0),1)

    for pt in imgpts_laser[id_laser]:
        if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
            image = cv2.circle(image, tuple(pt), 3, (0,0,255),1)
            
#cv2.imshow('annotation',image)
#k = cv2.waitKey(0) & 0xFF
#cv2.destroyAllWindows()

cv2.sav

# %%
id_valid
# Out:
# []

# %%
# Check if box proposal contains radar points
camera_matrix = np.array([[1.84541929e+03, 0.00000000e+00, 8.55802458e+02],
                 [0.00000000e+00 , 1.78869210e+03 , 6.07342667e+02],[0.,0.,1]])
dist_coeffs = np.array([2.51771602e-01,-1.32561698e+01,4.33607564e-03,-6.94637533e-03,5.95513933e+01])
rvecs = np.array([1.61803058, 0.03365624,-0.04003127])
tvecs = np.array([0.09138029,1.38369885,1.43674736])

cv2.namedWindow('annotation')

image = data['camera']['data'].copy()




for i,bb in enumerate(boxes):
    x1 = bb[0]
    y1 = bb[1]
    x2 = bb[2]
    y2 = bb[3]
    rect = Rectangle((x1, y1), (x2-x1), (y2-y1), linewidth=3, edgecolor='r', facecolor='none')
    
    image = cv2.rectangle(image, tuple((x1,y1)), tuple((x2,y2)), (0,0,255),3)
    
    
for pt in imgpts_radar:
    if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
        image = cv2.circle(image, tuple(pt), 3, (0,255,0),1)

for pt in imgpts_laser:
    if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
        image = cv2.circle(image, tuple(pt), 3, (0,0,255),1)
        
        
image = cv2.putText(image, str(data['scala']['sample_number']), (20,40), cv2.FONT_HERSHEY_SIMPLEX,  
               1, (0, 0, 255) , 1, cv2.LINE_AA) 

cv2.imshow('annotation',image)
k = cv2.waitKey(0) & 0xFF

cv2.destroyAllWindows()

# %%
#    float x,y,z;
#    float intensity;
#    float radialDistance;
#    float polAngle,aziAngle;
#    uint8_t layer_index;

id=np.where(pcl[:,6]>np.pi/2)[0]
pcl[id,6] = pcl[id,6] - 2*np.pi

id=np.where( (pcl[:,0]<=100) & (pcl[:,0]>2))[0]
pcl = pcl[id,:]


res_range = 0.2
res_angle = 0.2
max_range = 100
max_angle = 180
map = np.zeros((int(max_range/res_range),int(max_angle/res_angle)))
for i in np.arange(len(pcl)):
    range = int(pcl[i,4]/res_range)

    azimuth = int(pcl[i,6]*180/np.pi/res_angle) + int(max_angle/res_angle/2)
    
    if(range<(max_range/res_range) and azimuth>=0 and azimuth<(max_angle/res_angle)):
        map[range,azimuth]=1

# %%
plt.imshow(map)

# %%
y,x = map.nonzero()
for yy,xx in zip(y,x):
    map[yy:,xx] = 1
plt.imshow(map)

# %%
import skimage.morphology as morph

close = morph.binary_closing(map,selem=np.ones((1,5)))
open = morph.binary_opening(close,selem=np.ones((1,5)))
plt.imshow(open)

# %%
import polarTransform

RA_cartesian,_=polarTransform.convertToCartesianImage(open.transpose(),useMultiThreading=True,
        initialAngle=0, finalAngle=np.pi,order=0)

plt.imshow(RA_cartesian)

# %%
camera_matrix = np.array([[1.84541929e+03, 0.00000000e+00, 8.55802458e+02],
                 [0.00000000e+00 , 1.78869210e+03 , 6.07342667e+02],[0.,0.,1]])
dist_coeffs = np.array([2.51771602e-01,-1.32561698e+01,4.33607564e-03,-6.94637533e-03,5.95513933e+01])
rvecs = np.array([1.61803058, 0.03365624,-0.04003127])
tvecs = np.array([0.09138029,1.38369885,1.43674736])



cv2.namedWindow('annotation')

image = data['camera']['data'].copy()

x = -pcl[:,1] # lateral
y = pcl[:,0] # longi
z = pcl[:,2] # longi

objectPoints = np.stack([x,y,z],axis=1)

objectPoints = np.zeros((len(x),3))
objectPoints[:,0]=x
objectPoints[:,1]=y

imgpts, _ = cv2.projectPoints(objectPoints, rvecs, tvecs, camera_matrix, dist_coeffs)

imgpts=imgpts.squeeze(1)
imgpts=imgpts.astype('int')

for pt in imgpts:
    if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
        image = cv2.circle(image, tuple(pt), 3, (0,0,255),1)

y,x = RA_cartesian.nonzero()
y = y*res_range
x = (x - RA_cartesian.shape[1]/2)*res_range
z = np.zeros((1,len(x)))
objectPoints = np.zeros((len(x),3))
objectPoints[:,0]=x
objectPoints[:,1]=y
imgpts, _ = cv2.projectPoints(objectPoints, rvecs, tvecs, camera_matrix, dist_coeffs)
imgpts=imgpts.squeeze(1)
imgpts=imgpts.astype('int')

for pt in imgpts:
    if(pt[0]>0 and pt[0]<1920 and pt[1]>0 and pt[1]<1080):
        image = cv2.circle(image, tuple(pt), 3, (255,0,0),1)

        
image = cv2.putText(image, str(data['scala']['sample_number']), (20,40), cv2.FONT_HERSHEY_SIMPLEX,  
               1, (0, 0, 255) , 1, cv2.LINE_AA) 

cv2.imshow('annotation',image)
k = cv2.waitKey(0) & 0xFF

cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()

# %%
# Create an iterator on the dataset
ite = iter(db)

# iterate through the entire dataset
# it replays the data with the same order it has been recorded
# it s sequential, that is to say each data will be from one of the sensor, but
# not all at the same time
# Please, take into account that the timeofissue are ordered but the timestamp are from the sensor, so 
# an offset has to be applied

pos = [0,0]
absolute_angle = 0

data = db.df_filtered.to_numpy()

position=[]
position.append(pos)
init= True

pts = []

for i in range(len(db)):
    print(i,len(db))
    
    datas=db.GetSensorData(i)
    

    timestamp = datas['scala']['timestamp']

    #print('timestamp: ',timestamp,'timeofissue: ',timeofissue,'Sensor: ',sensor,'sample: ',sample)
    
    SteeringWheel,YawRate,VehSpdAvgDrvn = db.GetMostRecentOdometry(can_decoder,timestamp)
    
    
    rad.process(datas['radar_ch3']['data'],datas['radar_ch0']['data'],datas['radar_ch1']['data'],datas['radar_ch2']['data'])

    size_max = 10000

    azimuth = np.zeros(size_max,dtype = np.float32)
    elevation = np.zeros(size_max,dtype = np.float32)
    power = np.zeros(size_max,dtype = np.float32)
    doppler = np.zeros(size_max,dtype = np.float32)
    x = np.zeros(size_max,dtype = np.float32)
    y = np.zeros(size_max,dtype = np.float32)
    z = np.zeros(size_max,dtype = np.float32)
    v = np.zeros(size_max,dtype = np.float32)
    r = np.zeros(size_max,dtype = np.float32)
    
    NBPts = rad.get_pcl(r,azimuth,elevation,power,doppler, x,y,z,v,size_max)


    x = x[:NBPts]
    y = y[:NBPts]
    doppler = doppler[:NBPts]


    data = datas['scala']['data']
    sample_number = datas['scala']['sample_number']
    
    id = np.where((data[:,0]>2) & (data[:,0]<80) & (data[:,1]<20) & (data[:,1]>-20))[0]
    data=data[id,:]
    if(init):
        init=False
        previousTime = timestamp
        
        data = ApplyCalib(data,sample_number,absolute_angle)
        
        data2 = remove_ground(data.copy())
        
        id=np.where( (data2[:,0]<5) & (data2[:,1]<10) & (data2[:,1]>-10))[0]
        
        pts.append(data2[id,:3])
        continue
        
    # Estimate motiom
    dT_sec = (timestamp-previousTime)/1e6
    relative_angle = -YawRate*dT_sec
    absolute_angle +=relative_angle
    dist = VehSpdAvgDrvn*1000/3600 *dT_sec
    Dx = np.cos(absolute_angle/180*3.14)*dist
    Dy = np.sin(absolute_angle/180*3.14)*dist
    
    pos[0]+=Dx
    pos[1]+=Dy
    
    
    data2 = remove_ground(data.copy())
    data3 = ApplyCalib(data2.copy(),sample_number,absolute_angle/180*3.14)
    
    id=np.where((data3[:,0]<5) & (data3[:,1]<10) & (data3[:,1]>-10))[0]
    
    data3 = data3[id]
    
    data3[:,0]+=pos[0]
    data3[:,1]+=pos[1]
    
 
    previousTime = timestamp
    
    pts.append(data3[:,:3])
    
    #print(pos[0],pos[1])
    position.append(pos.copy())
    
position=np.vstack(position)
pts=np.vstack(pts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-156-1058c274e2c7> in <module>
#      20 pts = []
#      21
# ---> 22 for i in range(len(db)):
#      23     print(i,len(db))
#      24
#
# TypeError: 'int' object is not callable

# %%
position=np.vstack(position)
pts=np.vstack(pts)

# %%
plt.figure(figsize=(20,20))

plt.plot(pts[:,0],pts[:,1],'g.')
plt.plot(position[:,0],position[:,1],'r.')
#plt.plot(pts[1][:,0],pts[1][:,1],'b.')

# %%
# Create an iterator on the dataset
ite = iter(db)

# iterate through the entire dataset
# it replays the data with the same order it has been recorded
# it s sequential, that is to say each data will be from one of the sensor, but
# not all at the same time
# Please, take into account that the timeofissue are ordered but the timestamp are from the sensor, so 
# an offset has to be applied

pos = [0,0]
absolute_angle = 0

data = db.df_filtered.to_numpy()

position=[]
position.append(pos)
init= True

pts = []

for i in range(len(db)):
    
    ite = len(db) - 1 - i
    
    print(ite)
    
    datas=db.GetSensorData(ite)
    timestamp = datas['scala']['timestamp']
    SteeringWheel,YawRate,VehSpdAvgDrvn = db.GetMostRecentOdometry(can_decoder,timestamp)
    
    if(init):
        previousTime = timestamp
        init=False
        continue
        
    # Estimate motiom
    dT_sec = (previousTime - timestamp)/1e6
    relative_angle = -YawRate*dT_sec
    absolute_angle +=relative_angle
    dist = VehSpdAvgDrvn*1000/3600 *dT_sec
    Dx = np.cos(absolute_angle/180*3.14)*dist
    Dy = np.sin(absolute_angle/180*3.14)*dist
    
    pos[0]-=Dx
    pos[1]-=Dy
    
    ### Radar Processing
    rad.process(datas['radar_ch3']['data'],datas['radar_ch0']['data'],datas['radar_ch1']['data'],datas['radar_ch2']['data'])
    size_max = 10000
    azimuth = np.zeros(size_max,dtype = np.float32)
    elevation = np.zeros(size_max,dtype = np.float32)
    power = np.zeros(size_max,dtype = np.float32)
    doppler = np.zeros(size_max,dtype = np.float32)
    x = np.zeros(size_max,dtype = np.float32)
    y = np.zeros(size_max,dtype = np.float32)
    z = np.zeros(size_max,dtype = np.float32)
    v = np.zeros(size_max,dtype = np.float32)
    r = np.zeros(size_max,dtype = np.float32)
    NBPts = rad.get_pcl(r,azimuth,elevation,power,doppler, x,y,z,v,size_max)
    x = x[:NBPts]
    y = y[:NBPts]
    doppler = doppler[:NBPts]

    ### SCALA Processing    
    data = datas['scala']['data']
    sample_number = datas['scala']['sample_number']
    
    data = ApplyCalib(data,sample_number,absolute_angle)

    data2 = data#remove_ground(data.copy())
    
    # Keep only point on Dx range
    id = np.where( (data2[:,0]>2) & (data2[:,0]<(Dx+2)))[0]
    print(Dx)
                  
    data3 = data2[id,:3]
    
    data3[:,0]+=pos[0]
    data3[:,1]+=pos[1]
        
    previousTime = timestamp
    

    pts.append(data3[:,:3])
    
    #print(pos[0],pos[1])
    position.append(pos.copy())
    
position=np.vstack(position)
pts=np.vstack(pts)

# %%
rad.process(data1['radar_ch3']['data'],data1['radar_ch0']['data'],data1['radar_ch1']['data'],data1['radar_ch2']['data'])


NBPts = rad.get_pcl(r,azimuth,elevation,power,doppler, x,y,z,v,size_max)
x = x[:NBPts]
y = y[:NBPts]
doppler = doppler[:NBPts]

print('Number of 3D points: ',NBPts)


plt.figure(figsize=(5,10))
plt.plot(-data1['scala']['data'][:,1],data1['scala']['data'][:,0],'.')

plt.plot(y,x,'.')
id=np.where(doppler>200)[0]
plt.plot(y[id],x[id],'r.')
id=np.where(doppler<20)[0]
plt.plot(y[id],x[id],'k.')
plt.xlim(-50,50)
plt.ylim(0.,100)
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-c91133c56f92> in <module>
# ----> 1 rad.process(data1['radar_ch3']['data'],data1['radar_ch0']['data'],data1['radar_ch1']['data'],data1['radar_ch2']['data'])
#       2
#       3
#       4 NBPts = rad.get_pcl(r,azimuth,elevation,power,doppler, x,y,z,v,size_max)
#       5 x = x[:NBPts]
#
# NameError: name 'data1' is not defined

# %%
a,b = np.histogram(doppler,32,[0,255])
vV = np.argmax(a)*8
plt.plot(a)

# %%
np.median(doppler)
# Out:
# 51.0

# %%
plt.plot(doppler,'.')

# %%
map = np.zeros((200*4,700*4))

for i in range(len(pts)):
    x = int(pts[i,0]*4)
    y = int(-pts[i,1]*4+400)
    
    map[y,x]+=1

# %%
plt.figure(figsize=(20,10))
plt.imshow(map>0)

# %%
timestamp1,timeofissue,sample,sensor,sample_number,data1=db.GetSensorData(1000)

#print('timestamp: ',timestamp,'timeofissue: ',timeofissue,'Sensor: ',sensor,'sample: ',sample)

SteeringWheel,YawRate,VehSpdAvgDrvn = db.GetMostRecentOdometry(can_decoder,timestamp1)

id = np.where((data1[:,0]>2) & (data1[:,0]<80) & (data1[:,1]<20) & (data1[:,1]>-20))[0]
data1=data1[id,:]

data1=remove_ground(data1)

# %%
timestamp2,timeofissue,sample,sensor,sample_number,data2=db.GetSensorData(1001)

#print('timestamp: ',timestamp,'timeofissue: ',timeofissue,'Sensor: ',sensor,'sample: ',sample)

SteeringWheel,YawRate,VehSpdAvgDrvn = db.GetMostRecentOdometry(can_decoder,timestamp2)

id = np.where((data2[:,0]>2) & (data2[:,0]<80) & (data2[:,1]<20) & (data2[:,1]>-20))[0]
data2=data2[id,:]

data2=remove_ground(data2)

# %%
# Estimate motiom
absolute_angle=0
dT_sec = (timestamp2-timestamp1)/1e6
relative_angle = -YawRate*dT_sec
absolute_angle +=relative_angle
dist = VehSpdAvgDrvn*1000/3600 *dT_sec
Dx = np.cos(absolute_angle/180*3.14)*dist
Dy = np.sin(absolute_angle/180*3.14)*dist

print(Dx,Dy,relative_angle)
# Out:
# 1.1010555113677691 0.0001443752854118181 0.0075166875

# %%
plt.plot(-data1[:,1],data1[:,0],'.')
plt.plot(-data2[:,1],data2[:,0]+Dx,'.')

# %%
map = np.zeros((500,200,2))

for i in range(len(data1)):
    x = int(data1[i,0]*5)
    y = int(-data1[i,1]*5+100)
    
    if(x>0 and x<500 and y>0 and y<200):
        map[x,y,0]+=data1[i,3]
        
for i in range(len(data2)):
    x = int((data2[i,0]+Dx)*5)
    y = int(-data2[i,1]*5+100)
    
    if(x>0 and x<500 and y>0 and y<200):
        map[x,y,1]+=1#data2[i,3]

# %%
plt.imshow(np.abs(map[:,:,1]-map[:,:,0])>4)

# %% [markdown]
# ### Open the dataset

# %%
db = SyncReader('/media/julien/HD_RADAR/FinalDataset/Pitch0Deg/RECORD@2020-11-22_12.43.28',master='camera',tolerance=100000)
# Out:
# -------------------------------------------------------------------------
# - Sensors available:
# -     camera
# -     can
# -     radar_ch2
# -     scala
# -     radar_ch1
# -     radar_ch3
# -     radar_ch0
# -     gps
# -
# - You might use function "setSensorFilters" to select sensors you want to read!
# -------------------------------------------------------------------------
# Total tolerance errors:  0.0 %

# %%
data1000 = db.GetSensorData(1010)
data1001 = db.GetSensorData(1011)

# %%
print(data1000['scala']['timestamp'])
print(data1001['scala']['timestamp'])
# Out:
# 40268638
# 40308710

# %%
plt.imshow(data1000['camera']['data'])

# %%
can_decoder.decode(data1000['can']['data'])
# Out:
# [{'signals': {'TORSRotDir': 0,
#    'TORSLstTransType': 0,
#    'TORSRstOcrd': 0,
#    'TORSValidity': 0,
#    'TORSPulsCntr': 899,
#    'TORSTimestamp': 8969},
#   'timestamp': 40209196},
#  {'signals': {'TrnsOvrallEstTorqRatioV': 0,
#    'TrnsOvrallEstTorqRatio': 1.0,
#    'TrnsOutShftAngVelV': 0,
#    'TrnsOtptShftAngVelSnrPr': 1,
#    'TrnsOtptRotRCRstOcc': 0,
#    'TrnsOtptRotRCV': 0,
#    'TrnsRqHSABrkPrDcyRt': 0,
#    'TrnsDrvlneTqShpDisRq': 0,
#    'TrnsOutShftAngVel': 636.5,
#    'TrnsOtptRotRC': 450.515625,
#    'TransDsrdTrqRatio': 0.5304},
#   'timestamp': 40209197},
#  {'signals': {'TrnsTrqRqALC': 2,
#    'TIDCTR_TrqRespTyp': 0,
#    'TIDCTR_TrqReqVal': 1199.5,
#    'TIDCTR_TrqIntvTyp': 0,
#    'TPCTR_TrqIntrvnTyp': 0,
#    'TPCTR_TorqReqVal': 1199.5,
#    'TrnsPdCrkshftTqRqPVa': 12287,
#    'TrnsTrqCap': 1020},
#   'timestamp': 40209199},
#  {'signals': {'EngDgTrqCnvClUnlkRqd': 0,
#    'EngCyDactTqSmtAct': 0,
#    'ETGRReqType': 0,
#    'ETGRReqdGear': 0,
#    'EngBrkStat': 0,
#    'ACCmCltEngd': 0,
#    'TracCntlSysPwrtrnInhbt': 0,
#    'EngMtlProtAtv': 0,
#    'EngCyldrDeactReqd': 0,
#    'EngCylDeactMd': 0,
#    'EngColdHiIdleActive': 0,
#    'ParkNeutralSwStat': 1,
#    'ParkNeutralSwStatV': 0,
#    'DslPrtFltrIdlRgtnMdReq': 0,
#    'DslPartFltrClngAlgAct': 0,
#    'DslPartFltrClngAlgActM': 0,
#    'AccPdlPosPcntFullRngV': 0,
#    'EngPstOxgSnsDgAstRq': 0,
#    'EngRunng': 1,
#    'EngCrsCntrlMode': 0,
#    'CrsCtrlCnstSpdAct': 0,
#    'WrmUpShftPtrnRq': 0,
#    'EngAlwCltAdp': 0,
#    'EngIdlSpdRdcdRng': 744,
#    'BsTrgtEngIdlSpd': 600,
#    'AccPdlPosPcntFullRng': 38.823543},
#   'timestamp': 40210170},
#  {'signals': {'CrsCntrlSwStCanSwAct': 0,
#    'CrsCntrlSwStOnSwAct': 1,
#    'CrsCntrlSwStResSwAct': 0,
#    'CrsCntrlSwStSetSwAct': 0,
#    'CrsCntrlSwStSpdInSwAct': 0,
#    'CrsCntrlSwStSpDcSwAct': 0,
#    'CrsCntrlSwStSwDataIntgty': 0,
#    'CrsCntrlSwStatProtValue': 189,
#    'AdptCrsGapSwAct': 0,
#    'CrsCntCncRq': 0,
#    'CrsCntrlSwStAlvRollCnt': 3,
#    'AuxHtrRq': 0,
#    'AuxHtrAtv': 0,
#    'FuelMdSwActV': 0,
#    'FuelMdSwAct': 0,
#    'CrsSecSwStat': 0,
#    'DrvSelMdSw1Sta': 0,
#    'DrvSelMdSw2Sta': 1,
#    'DrvSelMdSw3Sta': 1,
#    'DrvSelMdSwStaARC': 0,
#    'CrsSpdLmtrSwStat': 9,
#    'CrsSpdLmtrSwStatARC': 0,
#    'CrsSecSwStatARC': 1,
#    'CrsSpdLmtrSwStatPVal': 15,
#    'CrsSecSwStatPVal': 15},
#   'timestamp': 40210171},
#  {'signals': {'EngRunng': 1, 'ClrCGMLgsDgInf': 0}, 'timestamp': 40210173},
#  {'signals': {'FuelCntlSysFltPrsnt': 0,
#    'FlPmpEDscOtptCmdSta': 1,
#    'EngRunng': 1,
#    'FuelDelPressRqd': 400,
#    'InstFuelFlowEst': 4.051755738,
#    'HiPresFuelPmpCntMd': 2,
#    'HiPresFuelPmpDelDur': 67,
#    'CmmndAirFuelRatio': 14.680168265},
#   'timestamp': 40210174},
#  {'signals': {'EngStlSvrAct': 0,
#    'EngStlSvrActARC': 0,
#    'AuxTransPrsCmndOn': 0,
#    'EngPrdctStdyStTorqV': 0,
#    'CrnkShftTrqMinOffCapV': 0,
#    'CrksftTqMinRunImCapV': 0,
#    'CrnkShftTrqMinOffCap': -42.5,
#    'CrksftTqMinRunImCap': -10.5,
#    'EngPrdctStdyStTorq': 305.0,
#    'EngPstnSnsngOpMode': 0,
#    'EVTCS_CrntTrqCapMd': 0,
#    'EVTCS_CmdTrqCapMd': 0},
#   'timestamp': 40210176},
#  {'signals': {'MassAirFloV': 0, 'MassAirFlo': 63.92}, 'timestamp': 40210177},
#  {'signals': {'CrksftTqMinImCapV': 0,
#    'CrksftMaxTrqLmtV': 1,
#    'DrvIntndCrksftTrqRw': 297.5,
#    'DrvIntndCrksftTrqMin': -10.5,
#    'CrksftTqMinImCap': -3.5,
#    'DrvIntndCrksftTrq': 297.5,
#    'CrksftMaxTrqLmt': 390.0},
#   'timestamp': 40211168},
#  {'signals': {'EngTrqRdFlrSt': 0,
#    'EngTrqActExtRngV': 0,
#    'EngTrqActExtRng': 304.5,
#    'AuxHtrAlwd': 0,
#    'AccPosV': 0,
#    'EngTrqDrRqdExtRngV': 0,
#    'EngTrqDrRqdExtRng': 297.5,
#    'FuelFltRmnLf': 0.0,
#    'HillDscntCtrlSwStat': 0,
#    'HillDscntCtrlSwStatARC': 0,
#    'AccPos': 38.823543,
#    'AppCltchAutSrtIO': 0,
#    'GlwPlgCrnkDelAct': 0,
#    'HillDscntCtrlSwStatPVal': 0},
#   'timestamp': 40211169},
#  {'signals': {'unknow': 1152921983220056063}, 'timestamp': 40211171},
#  {'signals': {'EngManfldAbsPrsV': 0,
#    'EngTrqMaxExtRngV': 0,
#    'EngTrqMaxExtRng': 335.0,
#    'EngTrqMinExtRngV': 0,
#    'EngTrqMinExtRng': -42.5,
#    'EngManfldAbsPrs': 97.0,
#    'CSTATRS_LmtgStat': 0,
#    'CSTATRS_ReqStat': 0},
#   'timestamp': 40211172},
#  {'signals': {'PTImmblzerInfo': 533086118099288064}, 'timestamp': 40212172},
#  {'signals': {'ThrPosV': 0,
#    'AutoMdSpdLmtStat': 0,
#    'SpdLmtrSpdWrngAct': 0,
#    'EngNEmsnsRelMalfAct': 0,
#    'EngEmsRelMalfIndReq': 1,
#    'ThrPos': 49.019625,
#    'EngBstPrsIndV': 1,
#    'EngCstFlCutAct': 0,
#    'EngOilStrvtnIO': 0,
#    'CrsSpdLmtrDrvSelSpd': 76.0,
#    'CrsCntlDrSelSpdAct': 0,
#    'FuelFltLifRstPerf': 0,
#    'ACCompCmnd': 0,
#    'InstFuelConsmpRate': 20.575000000000003,
#    'EngBstPrsInd': 0.0,
#    'ACCmpNrmLdGrdAld': 6.300000000000001},
#   'timestamp': 40212174},
#  {'signals': {'VehSpdAvgDrvnV': 0,
#    'VehSpdAvgDrvn': 92.234375,
#    'VehSpdAvgDrvnSrc': 0,
#    'DistRollCntAvgDrvnV': 0,
#    'DstRolCntAvgDrnRstOc': 0,
#    'DistRollCntAvgDrvn': 804.25,
#    'VehSpdAvgNDrvnV': 0,
#    'VehSpdAvgNDrvn': 92.078125,
#    'DistRollCntAvgDrvnSrc': 0,
#    'DstRolCntAvgNonDrvnV': 0,
#    'DstRolCntAvNDrRstOc': 0,
#    'DstRolCntAvgNonDrvn': 626.125},
#   'timestamp': 40212176},
#  {'signals': {'FlInjRlCtRstOcc': 0,
#    'GenFldDutCycV': 0,
#    'GenFld': 0,
#    'EngSpdLmtnMdAct': 0,
#    'VehTopSpdLmtMdAct': 0,
#    'ACRfHiSdFldPrsV': 0,
#    'GenStptDtCycPtOvrAct': 0,
#    'FlInjRlCt': 1.0225227056,
#    'GenFldDutCyc': 18.039222,
#    'VehTopSpdLmtArbVal': 174,
#    'EngCoolFanSpd': 0.784314,
#    'EngOilRmnLf': 0.0,
#    'ACRfHiSdFldPrs': 210},
#   'timestamp': 40212178},
#  {'signals': {'FuelAlcoholCompV': 0,
#    'EmnsRelFuelLvlLw': 0,
#    'FuelLvlEmnsRelStat': 0,
#    'FuelAlchlCompAdptnPrg': 0,
#    'EngFuelCntlState': 2,
#    'FuelAlcoholComp': 0.0},
#   'timestamp': 40212180},
#  {'signals': {'BarPrsAbsV': 0,
#    'EngCltTmpV': 0,
#    'EngIntAirTmpV': 0,
#    'OAT_PT_EstM': 1,
#    'OAT_PT_EstV': 0,
#    'LegDiagStndCndMet': 1,
#    'LegDiagStndCndFltPr': 0,
#    'EngWrmUpAch': 1,
#    'BarPrsAbs': 100.5,
#    'EngCltTmp': 90,
#    'EngIntAirTmp': 1,
#    'OAT_PT_Est': -4.5,
#    'LegDiagColdStCndMet': 0,
#    'LegDiagColdStCndFltPr': 0,
#    'EngOilHotIO': 0,
#    'EngIntAirTmpM': 0,
#    'LDMinEngCltTmpRchd': 0,
#    'CdClrInhbt': 0,
#    'DslExhFldRmngDstHRsV': 0,
#    'LegPstDTCClrDrvCyCm': 1,
#    'LDMaxEngCltTmpRchd': 0,
#    'DslExhFldRmngDstHRs': 0},
#   'timestamp': 40213170},
#  {'signals': {'EngOilTmpV': 0,
#    'EngOilPrsV': 0,
#    'EngOilPrsLwIO': 0,
#    'EngOilLvlLwIO': 0,
#    'EngOilChngIO': 1,
#    'EngHotFuelEnrchmntIO': 0,
#    'EngHt_StpEngIO': 0,
#    'AirCndOffIO': 0,
#    'EngOilTmp': -40,
#    'EngOilPrs': 0,
#    'RdcdPwrIO': 0,
#    'a_12VBatSysUnstab': 0,
#    'CkFlFilrCapIO': 0,
#    'FlLvlPctV': 0,
#    'FuelTotCap': 82.5,
#    'FlLvlPct': 60.784335,
#    'DslGlwPlgIO': 0,
#    'EngWtrInFlIO': 0,
#    'PTExPrtclFltrWrnIO': 0,
#    'PTHiElecLdReqd': 0,
#    'FuelFltChgNwIO': 0,
#    'PTExPrtclFltrWrn2IO': 0,
#    'EngShtdwnPndgIO': 0,
#    'EngShtdwnAct': 0,
#    'PTExPrtclFltWrng3IO': 0,
#    'PTExPartFltManRegStat': 0,
#    'EngAftrRnIndReq': 0},
#   'timestamp': 40213172},
#  {'signals': {'ETC_EngOpMd': 1,
#    'ETC_FrmCntr': 9,
#    'ETC_UnsdRsrvd': 0,
#    'ETC_RefEngSpd': 1920,
#    'ETC_MaxTorq': -120.5,
#    'ETC_MinRunTorq': -93.0,
#    'ETC_MinTorq': -41.5,
#    'PrplsnTrqRelCap': 99.0},
#   'timestamp': 40213174},
#  {'signals': {'BrkPdlModTrvlV': 0,
#    'BrkPdlModTrvl': 0,
#    'BrkPedPosAlvRolngCnt': 2,
#    'BrkPdlInTrvPrt': 2,
#    'BrkPedTrvlAchvd': 0,
#    'BrkPedTrvlAchvdV': 0,
#    'BrkPdlPos': 1.568628,
#    'BrkPdlPosGrad': 0,
#    'BrkAppSnsrHmPosLrnd': 1,
#    'NotEventStat': 0,
#    'BrkPdlChkData': 28561},
#   'timestamp': 40217100},
#  {'signals': {'WRSLDWhlDisTpRC': 0,
#    'WRSLDSeqNum': 2,
#    'WRSLDWhlRotStatRst': 0,
#    'WRSLDWhlDistVal': 0,
#    'WRSLDWhlDistPlsCntr': 332,
#    'WRSLDWhlDistTmstm': 48121,
#    'WRSRDWhlDisTpRC': 0,
#    'WRSRDSeqNum': 2,
#    'WRSRDWhlRotStatRst': 0,
#    'WRSRDWhlDistVal': 0,
#    'WRSRDWhlDistPlsCntr': 582,
#    'WRSRDWhlDistTmstm': 22270},
#   'timestamp': 40217102},
#  {'signals': {'TrnsAliveRC': 2,
#    'TESR_EngSpdIntTyp': 0,
#    'TESR_EngSpdCntlRsp': 0,
#    'TESR_EngSpdRqVal': 0,
#    'TrnsCyDactTransStat': 0,
#    'TrnsEngSpdRqProt': 16382,
#    'TransNtrlCntrlMdStat': 0,
#    'TrnTrbAngVlV': 0,
#    'TrnGrRatV': 0,
#    'EngBrkDsblReqd': 0,
#    'TrnPrfAlgShfAtv': 0,
#    'TrnsRtoCntlSysFlt': 0,
#    'TrnsGrgShftAct': 0,
#    'TrnTrbAngVl': 2013.75,
#    'TrnGrRat': 1.0},
#   'timestamp': 40217104},
#  {'signals': {'WRSLNDWhlDisTpRC': 0,
#    'WRSLNDSeqNum': 2,
#    'WRSLNDWhlRotStRst': 0,
#    'WRSLNDWhlDistVal': 0,
#    'WRSLNDWhlDistPCntr': 625,
#    'WRSLNDWhlDistTstm': 1064,
#    'WRSRNDWhlDisTpRC': 0,
#    'WRSRNDSeqNum': 2,
#    'WRSRNDWhlRotStRst': 0,
#    'WRSRNDWhlDistVal': 0,
#    'WRSRNDWhlDistPCntr': 381,
#    'WRSRNDWhlDistTstm': 55232},
#   'timestamp': 40218098},
#  {'signals': {'LKATrqOvrlTrqDStat': 0,
#    'LKAElPwrStTtlTqDlvd': 0.03,
#    'HndsOffStrWhlDtStV': 0,
#    'HndsOffStrWhlDtSt': 0,
#    'HndsOffStrWhlDtMd': 0,
#    'LKATrqOvrlDltTrqDlvd': 0.0,
#    'LKATrqOvrlDlvdRC': 0,
#    'LKATrqOvrlStatChksm': 509,
#    'LKADrvAppldTrqV': 1,
#    'LKADrvAppldTrq': -0.01},
#   'timestamp': 40218100},
#  {'signals': {'TrnsAntcptdCrpTrqRRnV': 0,
#    'TDslPrtFltrIdlRgtnMdAtv': 0,
#    'TransCrnkPermsnStat': 0,
#    'WrmUpShftPtrn': 0,
#    'TrnCltAdpAtv': 0,
#    'TrnsInpCltchStat': 0,
#    'TrnsAntcptdCrpTrqRRn': 0.0,
#    'TransCrnkPermsnStatV': 0,
#    'TrnsTrqCnvCltCmndMd': 2,
#    'TrnsTrqCnvCltCmdMdF': 0,
#    'AutoTransGrSftDirect': 0,
#    'AutoTransGrSftDirectFl': 0,
#    'TrnsStEconMdOvrd': 0,
#    'TrnsStSprtMdOvrd': 1,
#    'TrnsStTwHaulMdOvrd': 1,
#    'TrnsStWntrMdOvrd': 1,
#    'TrnsInpCltchStatV': 0,
#    'DrvlneTrqStabStat': 0,
#    'TrnsTrqCnvCltDsrSlp': 115,
#    'TransMinVoltReq': 0.0,
#    'TransVehTopSpdLim': 510},
#   'timestamp': 40218102},
#  {'signals': {'APAEngTrqRdctnAct': 0,
#    'CSETRER_TqIntvnTyp': 0,
#    'CSETRER_TorqReqVal': 1199.5,
#    'TCAliveRC': 3,
#    'ChsSysEngTrqReqProt': 12286,
#    'TracCntrlMaxTorqIncRt': 1008},
#   'timestamp': 40218104},
#  {'signals': {'aaa': 5187874093987397631}, 'timestamp': 40218110},
#  {'signals': {'StrWhAngV': 0,
#    'StrWhlAngSenCalStat': 2,
#    'StrWhlAngSenTyp': 0,
#    'StrWhAngMsk': 1,
#    'StrWhAng': -5.1875,
#    'StrWhAngGrdV': 1,
#    'StWhlAngAliveRollCnt': 3,
#    'StrWhAngGrdMsk': 0,
#    'StrWhAngGrd': 0,
#    'StrAngSnsChksm': 0},
#   'timestamp': 40219111},
#  {'signals': {'BrkPdlDrvAppPrsDetcdV': 0,
#    'BrkPdlDrvAppPrsDetcd': 0,
#    'TrnsBrkSysCltchRelRqd': 0,
#    'VSELatAccV': 0,
#    'VSELatAcc': 0.609375,
#    'BSTGRReqType': 0,
#    'BSTGRReqdGear': 0,
#    'ACCBrkngAct': 0,
#    'ABSAtv': 0,
#    'ABSFld': 0,
#    'TCSysAtv': 0,
#    'TCSysEnbld': 1,
#    'TracCntrlSysDrIntnt': 1,
#    'IMUDataMsk': 0,
#    'VSEAct': 0,
#    'VhDynCntlSysSt': 0,
#    'VehDynYawRateV': 0,
#    'VehDynYawRate': -0.75,
#    'DrvIndpntBrkAppAct': 0,
#    'EnhDrvMdSwChUseRq': 0,
#    'WhlSlpSt': 0,
#    'VehDynOvrUndrStrV': 0,
#    'VehDynOvrUndrStr': 0.0},
#   'timestamp': 40219118},
#  {'signals': {'aaa': 186296078303231}, 'timestamp': 40219120},
#  {'signals': {'TreInfMonSysRstReq': 0,
#    'HUDActv': 1,
#    'CrshAlrtDrvrSlctdType': 0,
#    'TrlrHWIntrfcVDA': 0,
#    'MpDataAvlbl': 0,
#    'DrSbltAtcV': 1,
#    'BatVltV': 1,
#    'TrlrHtchSwAtv': 1,
#    'DrId': 0,
#    'DrSbltAtc': 0,
#    'BldUpArDet': 0,
#    'PDAjrSwAtv': 0,
#    'DDAjrSwAtv': 0,
#    'RLDoorAjarSwAct': 0,
#    'RRDoorAjarSwAct': 0,
#    'ChmMstrVDA': 0,
#    'IPCVDA': 0,
#    'HeadUpDispVDA': 0,
#    'EnrgMgtLdShdRq': 0,
#    'BatVlt': 3.0,
#    'CntrldAccRd': 1,
#    'StrCustStngReq': 5,
#    'RstrCustFctrDef': 1,
#    'DrvlnCustStngReq': 0,
#    'LnCat': 1,
#    'RdSpdCatType': 3,
#    'SprtLnRd': 0,
#    'SusCustStngReq': 0,
#    'ChmAct': 0,
#    'PsSbltAtcV': 0,
#    'PsSbltAtc': 1,
#    'HapticSeatVDA': 1,
#    'TrlrBrkDsplyAct': 1,
#    'FncRdClass': 7,
#    'DDAjrSwAtvM': 1,
#    'TCSysDisSwAtv_12A': 1,
#    'TCSysDisSwAtvARC': 3,
#    'ValetMdAct': 1,
#    'DrvrDrAjrSwVDA': 1,
#    'AutoMdSpdLmtCnfrmd': 1,
#    'Ky_IdDevPr': 1},
#   'timestamp': 40219121},
#  {'signals': {'TrnsTrqCnvCltCmndMd': 2,
#    'TransEstGearV': 0,
#    'TransEstGear': 5,
#    'TopTrvlCltchSwActV': 0,
#    'TopTrvlCltchSwAct': 0,
#    'AutoTransGrSftDirect': 0,
#    'AutoTransComndGear': 5,
#    'TrnsSkpShftIO': 0,
#    'EngRecmndUpshftIO': 0,
#    'DrShftCntrlReqDndIO': 0,
#    'DrvtShftCntrlTrgtGear': 0,
#    'TrnsRngInhbtStat': 0,
#    'TrnsShftLvrPosV': 0,
#    'TrnsShftLvrPos': 4,
#    'ElcRngSelDrvAct': 0,
#    'CltStartSwAtvV': 0,
#    'CltStartSwAtv': 0,
#    'TrnsSftMdStat': 0,
#    'TrnsShftLvrLckRqd': 0,
#    'TrnCrpMdAtv': 0,
#    'TmpDrvrShftCtlAct': 0,
#    'TrnShftPtrnActStat': 0,
#    'TransTUDMdStat': 0,
#    'CltchPdlActPosV': 0,
#    'EngRecDwnshftIO': 0,
#    'PropSysBrkLitsReqd': 0,
#    'TrnsPattSelEcnMdOCm': 0,
#    'TrnsFldPrsPrsnt': 1,
#    'TrnsEngdStateV': 0,
#    'TrnsEngdState': 1,
#    'CltchPdlActPos': 0.0},
#   'timestamp': 40220113},
#  {'signals': {'PTSnsdBrkPdlInfARC': 2,
#    'TrnsAuxPmpAct': 0,
#    'PSBPI_PTSnBrkPdlPsV': 0,
#    'PSBPI_PTSnBrkPdlPs': 1.960785,
#    'AccPos': 39.2157,
#    'EngSpdMaxCapRdcdRng': 7608,
#    'PTSnsdBrkPdlInfPVal': 401},
#   'timestamp': 40221113},
#  {'signals': {'EngRunAtv': 1,
#    'PT_CrnkAct': 0,
#    'PTCrnkAbrted': 0,
#    'PTRunAbrt': 0,
#    'PTO_PT_RunAbrtd': 0,
#    'EngIdlAtv': 0,
#    'EngSpdStat': 0,
#    'EngSpd': 2116.75,
#    'AccActPosV': 0,
#    'CrsCntAtv': 0,
#    'CrsCntEnbld': 1,
#    'DrvThrottlOvrrdDet': 0,
#    'DrThrtlOvrdDetAlvRlCnt': 2,
#    'DrThrtlOvrrdDetProtVal': 2,
#    'AccActPos': 38.823543,
#    'SpdLmtrSpdWrngEnbld': 0,
#    'PFEngSpdCmndSpcd': 0,
#    'PltfrmEngSpdCmdInhtRq': 0,
#    'EngCylDeactMd': 0,
#    'PT_BrkPedDscrtInpStatV': 0,
#    'PT_BrkPedDscrtInpStat': 0,
#    'RmVhStrtEngRng': 0,
#    'EngCylDactEvntPndg': 0,
#    'Eng12vStrtrMtrCmmdOn': 0,
#    'EngCntrlRunCrnkTrmSt': 1,
#    'EngAirIntBstPrV': 1,
#    'EngAirIntBstPr': 0},
#   'timestamp': 40221115},
#  {'signals': {'PTACCAct': 0,
#    'TrnsEngSpdReqFld': 0,
#    'EngPrdctTrqTnsRqLmS': 0,
#    'EngPrdctTrqTnsRqStat': 0,
#    'EngActStdyStTorqV': 0,
#    'AccKdwnAtv': 0,
#    'EngImmTrqTnsRqLmSt': 0,
#    'EngImmTrqTnsRqStat': 0,
#    'EngNTrnsRegStdyStTqV': 0,
#    'CTSS_StbltyTyp': 0,
#    'CTSS_StbltyLvl': 0,
#    'EngActStdyStTorq': 304.0,
#    'EngNTrnsRegStdyStTq': 304.0,
#    'CrksftNTrnsRegCmdTq': 297.0},
#   'timestamp': 40221117},
#  {'signals': {'PedFrndlyAlrtCsSetAvl': 0,
#    'PedFrndlyAlrtCsCrStVal': 0,
#    'PFAS_PFASndGenEn': 0,
#    'PFAS_PFAFwdSnd': 0,
#    'PFAS_PFARevSnd': 0,
#    'PFAS_PFACrsOvrSpd': 2,
#    'PFAS_PFASndVolCtrl': 1.568628,
#    'PFAS_PFASysStat': 0,
#    'PFAS_SrvPedAlrtIO': 0},
#   'timestamp': 40221119},
#  {'signals': {'TORSRotDir': 0,
#    'TORSLstTransType': 0,
#    'TORSRstOcrd': 0,
#    'TORSValidity': 0,
#    'TORSPulsCntr': 928,
#    'TORSTimestamp': 12104},
#   'timestamp': 40221121},
#  {'signals': {'TrnsOvrallEstTorqRatioV': 0,
#    'TrnsOvrallEstTorqRatio': 1.0,
#    'TrnsOutShftAngVelV': 0,
#    'TrnsOtptShftAngVelSnrPr': 1,
#    'TrnsOtptRotRCRstOcc': 0,
#    'TrnsOtptRotRCV': 0,
#    'TrnsRqHSABrkPrDcyRt': 0,
#    'TrnsDrvlneTqShpDisRq': 0,
#    'TrnsOutShftAngVel': 636.75,
#    'TrnsOtptRotRC': 450.796875,
#    'TransDsrdTrqRatio': 0.5304},
#   'timestamp': 40222110},
#  {'signals': {'TrnsTrqRqALC': 3,
#    'TIDCTR_TrqRespTyp': 0,
#    'TIDCTR_TrqReqVal': 1199.5,
#    'TIDCTR_TrqIntvTyp': 0,
#    'TPCTR_TrqIntrvnTyp': 0,
#    'TPCTR_TorqReqVal': 1199.5,
#    'TrnsPdCrkshftTqRqPVa': 12286,
#    'TrnsTrqCap': 1020},
#   'timestamp': 40222112},
#  {'signals': {'FuelCntlSysFltPrsnt': 0,
#    'FlPmpEDscOtptCmdSta': 1,
#    'EngRunng': 1,
#    'FuelDelPressRqd': 400,
#    'InstFuelFlowEst': 4.0351541840000005,
#    'HiPresFuelPmpCntMd': 2,
#    'HiPresFuelPmpDelDur': 67,
#    'CmmndAirFuelRatio': 14.680168265},
#   'timestamp': 40222114},
#  {'signals': {'MassAirFloV': 0, 'MassAirFlo': 63.92}, 'timestamp': 40222116},
#  {'signals': {'BkupPwrModeMstrVDA': 1,
#    'SysBkupPwrMdEn': 0,
#    'SysBkUpPwrMd': 2,
#    'PMMRunCrkTrmSt': 1,
#    'PMMAccTrmSt': 1,
#    'SysPwrMd': 2,
#    'RmVehStrRq': 0,
#    'PTORmStMsEngStRq': 0,
#    'PTORSMstrEngShtReq': 0,
#    'ACCompModReq': 1,
#    'ACCompNormLdV': 0,
#    'ACCompSysVDA': 1,
#    'ImmblzrPreRelPswdStat': 0,
#    'ImmblzrPreRelPswrd': 0,
#    'ThrtlPrgrsnReq': 0,
#    'EngOilLfRstRq': 0,
#    'PrkBrkSwAtv': 0,
#    'PrkBrkVDA': 1,
#    'TrStLgMdAtv': 0,
#    'ElvtdIdlCstStReq': 0,
#    'ACCompNormLd': 0.0,
#    'ACCmpsrFldOn': 0,
#    'PrkBrkVDM': 1,
#    'BkupPwrModeMstrVDM': 1,
#    'ACCompSysVDM': 1,
#    'DispMeasSys': 0,
#    'SIRDpl': 0,
#    'AirbgVDA': 1,
#    'FuelFltLfRstRqd': 0},
#   'timestamp': 40223426},
#  {'signals': {'BrkPdlModTrvlV': 0,
#    'BrkPdlModTrvl': 0,
#    'BrkPedPosAlvRolngCnt': 3,
#    'BrkPdlInTrvPrt': 1,
#    'BrkPedTrvlAchvd': 0,
#    'BrkPedTrvlAchvdV': 0,
#    'BrkPdlPos': 1.568628,
#    'BrkPdlPosGrad': 0,
#    'BrkAppSnsrHmPosLrnd': 1,
#    'NotEventStat': 0,
#    'BrkPdlChkData': 28561},
#   'timestamp': 40225647},
#  {'signals': {'WRSLDWhlDisTpRC': 0,
#    'WRSLDSeqNum': 3,
#    'WRSLDWhlRotStatRst': 0,
#    'WRSLDWhlDistVal': 0,
#    'WRSLDWhlDistPlsCntr': 337,
#    'WRSLDWhlDistTmstm': 50747,
#    'WRSRDWhlDisTpRC': 0,
#    'WRSRDSeqNum': 3,
#    'WRSRDWhlRotStatRst': 0,
#    'WRSRDWhlDistVal': 0,
#    'WRSRDWhlDistPlsCntr': 586,
#    'WRSRDWhlDistTmstm': 24371},
#   'timestamp': 40226684},
#  {'signals': {'WRSLNDWhlDisTpRC': 0,
#    'WRSLNDSeqNum': 3,
#    'WRSLNDWhlRotStRst': 0,
#    'WRSLNDWhlDistVal': 0,
#    'WRSLNDWhlDistPCntr': 630,
#    'WRSLNDWhlDistTstm': 3704,
#    'WRSRNDWhlDisTpRC': 0,
#    'WRSRNDSeqNum': 3,
#    'WRSRNDWhlRotStRst': 0,
#    'WRSRNDWhlDistVal': 0,
#    'WRSRNDWhlDistPCntr': 386,
#    'WRSRNDWhlDistTstm': 57869},
#   'timestamp': 40227689},
#  {'signals': {'StrWhAngV': 0,
#    'StrWhlAngSenCalStat': 2,
#    'StrWhlAngSenTyp': 0,
#    'StrWhAngMsk': 1,
#    'StrWhAng': -5.1875,
#    'StrWhAngGrdV': 1,
#    'StWhlAngAliveRollCnt': 0,
#    'StrWhAngGrdMsk': 0,
#    'StrWhAngGrd': 0,
#    'StrAngSnsChksm': 768},
#   'timestamp': 40227691},
#  {'signals': {'aaa': 186296078303231}, 'timestamp': 40227694},
#  {'signals': {'aaa': 478613209087}, 'timestamp': 40227696},
#  {'signals': {'EnhSvVehTopSpdLmR': 0,
#    'EnhSvVTpSpdLVlARC': 0,
#    'EnhSvVehTopSpdLimP': 0,
#    'EnhSvVehTopSpdLim': 510},
#   'timestamp': 40228685},
#  {'signals': {'TrnsPFShftPattSwARC': 0,
#    'TrnsPFShftPattSw1Act': 0,
#    'TrnsPFShftPattSw2Act': 0,
#    'TrnsPFShftPattSw3Act': 0,
#    'TrnsPFShftPattSw4Act': 0,
#    'OvrdrvDsblReqd': 0,
#    'PFTrnsTUDSwStAlvRC': 0,
#    'PFTrnsTUDEnSwSt': 2,
#    'PFTrnsTUDSwSt': 0,
#    'PFTrnsTUDSecSwSt': 0,
#    'PTShftPtrnOvrdAct': 1},
#   'timestamp': 40228687},
#  {'signals': {'unknow': 1152921983220056063}, 'timestamp': 40230685},
#  {'signals': {'aaa': 216172782113849343}, 'timestamp': 40231707},
#  {'signals': {'ImoInf': 533113605889982464}, 'timestamp': 40231711},
#  {'signals': {'aaa': 24867033586991103}, 'timestamp': 40231713},
#  {'signals': {'PTSnsdBrkPdlInfARC': 3,
#    'TrnsAuxPmpAct': 0,
#    'PSBPI_PTSnBrkPdlPsV': 0,
#    'PSBPI_PTSnBrkPdlPs': 1.960785,
#    'AccPos': 39.2157,
#    'EngSpdMaxCapRdcdRng': 7608,
#    'PTSnsdBrkPdlInfPVal': 401},
#   'timestamp': 40231716},
#  {'signals': {'EngRunAtv': 1,
#    'PT_CrnkAct': 0,
#    'PTCrnkAbrted': 0,
#    'PTRunAbrt': 0,
#    'PTO_PT_RunAbrtd': 0,
#    'EngIdlAtv': 0,
#    'EngSpdStat': 0,
#    'EngSpd': 2117.0,
#    'AccActPosV': 0,
#    'CrsCntAtv': 0,
#    'CrsCntEnbld': 1,
#    'DrvThrottlOvrrdDet': 0,
#    'DrThrtlOvrdDetAlvRlCnt': 3,
#    'DrThrtlOvrrdDetProtVal': 1,
#    'AccActPos': 38.823543,
#    'SpdLmtrSpdWrngEnbld': 0,
#    'PFEngSpdCmndSpcd': 0,
#    'PltfrmEngSpdCmdInhtRq': 0,
#    'EngCylDeactMd': 0,
#    'PT_BrkPedDscrtInpStatV': 0,
#    'PT_BrkPedDscrtInpStat': 0,
#    'RmVhStrtEngRng': 0,
#    'EngCylDactEvntPndg': 0,
#    'Eng12vStrtrMtrCmmdOn': 0,
#    'EngCntrlRunCrnkTrmSt': 1,
#    'EngAirIntBstPrV': 1,
#    'EngAirIntBstPr': 0},
#   'timestamp': 40232751},
#  {'signals': {'PTACCAct': 0,
#    'TrnsEngSpdReqFld': 0,
#    'EngPrdctTrqTnsRqLmS': 0,
#    'EngPrdctTrqTnsRqStat': 0,
#    'EngActStdyStTorqV': 0,
#    'AccKdwnAtv': 0,
#    'EngImmTrqTnsRqLmSt': 0,
#    'EngImmTrqTnsRqStat': 0,
#    'EngNTrnsRegStdyStTqV': 0,
#    'CTSS_StbltyTyp': 0,
#    'CTSS_StbltyLvl': 0,
#    'EngActStdyStTorq': 303.5,
#    'EngNTrnsRegStdyStTq': 303.5,
#    'CrksftNTrnsRegCmdTq': 297.5},
#   'timestamp': 40232754},
#  {'signals': {'FuelCntlSysFltPrsnt': 0,
#    'FlPmpEDscOtptCmdSta': 1,
#    'EngRunng': 1,
#    'FuelDelPressRqd': 400,
#    'InstFuelFlowEst': 3.991208894,
#    'HiPresFuelPmpCntMd': 2,
#    'HiPresFuelPmpDelDur': 67,
#    'CmmndAirFuelRatio': 14.680168265},
#   'timestamp': 40232757},
#  {'signals': {'MassAirFloV': 0, 'MassAirFlo': 62.51}, 'timestamp': 40232759},
#  {'signals': {'TORSRotDir': 0,
#    'TORSLstTransType': 0,
#    'TORSRstOcrd': 0,
#    'TORSValidity': 0,
#    'TORSPulsCntr': 957,
#    'TORSTimestamp': 15236},
#   'timestamp': 40233748},
#  {'signals': {'TrnsOvrallEstTorqRatioV': 0,
#    'TrnsOvrallEstTorqRatio': 1.0,
#    'TrnsOutShftAngVelV': 0,
#    'TrnsOtptShftAngVelSnrPr': 1,
#    'TrnsOtptRotRCRstOcc': 0,
#    'TrnsOtptRotRCV': 0,
#    'TrnsRqHSABrkPrDcyRt': 0,
#    'TrnsDrvlneTqShpDisRq': 0,
#    'TrnsOutShftAngVel': 636.75,
#    'TrnsOtptRotRC': 450.796875,
#    'TransDsrdTrqRatio': 0.5304},
#   'timestamp': 40234731},
#  {'signals': {'TrnsTrqRqALC': 0,
#    'TIDCTR_TrqRespTyp': 0,
#    'TIDCTR_TrqReqVal': 1199.5,
#    'TIDCTR_TrqIntvTyp': 0,
#    'TPCTR_TrqIntrvnTyp': 0,
#    'TPCTR_TorqReqVal': 1199.5,
#    'TrnsPdCrkshftTqRqPVa': 12289,
#    'TrnsTrqCap': 1020},
#   'timestamp': 40234733},
#  {'signals': {'EngDgTrqCnvClUnlkRqd': 0,
#    'EngCyDactTqSmtAct': 0,
#    'ETGRReqType': 0,
#    'ETGRReqdGear': 0,
#    'EngBrkStat': 0,
#    'ACCmCltEngd': 0,
#    'TracCntlSysPwrtrnInhbt': 0,
#    'EngMtlProtAtv': 0,
#    'EngCyldrDeactReqd': 0,
#    'EngCylDeactMd': 0,
#    'EngColdHiIdleActive': 0,
#    'ParkNeutralSwStat': 1,
#    'ParkNeutralSwStatV': 0,
#    'DslPrtFltrIdlRgtnMdReq': 0,
#    'DslPartFltrClngAlgAct': 0,
#    'DslPartFltrClngAlgActM': 0,
#    'AccPdlPosPcntFullRngV': 0,
#    'EngPstOxgSnsDgAstRq': 0,
#    'EngRunng': 1,
#    'EngCrsCntrlMode': 0,
#    'CrsCtrlCnstSpdAct': 0,
#    'WrmUpShftPtrnRq': 0,
#    'EngAlwCltAdp': 0,
#    'EngIdlSpdRdcdRng': 744,
#    'BsTrgtEngIdlSpd': 600,
#    'AccPdlPosPcntFullRng': 38.823543},
#   'timestamp': 40234734},
#  {'signals': {'EngRunng': 1, 'ClrCGMLgsDgInf': 0}, 'timestamp': 40234736},
#  {'signals': {'EngStlSvrAct': 0,
#    'EngStlSvrActARC': 0,
#    'AuxTransPrsCmndOn': 0,
#    'EngPrdctStdyStTorqV': 0,
#    'CrnkShftTrqMinOffCapV': 0,
#    'CrksftTqMinRunImCapV': 0,
#    'CrnkShftTrqMinOffCap': -42.5,
#    'CrksftTqMinRunImCap': -10.5,
#    'EngPrdctStdyStTorq': 303.5,
#    'EngPstnSnsngOpMode': 0,
#    'EVTCS_CrntTrqCapMd': 0,
#    'EVTCS_CmdTrqCapMd': 0},
#   'timestamp': 40234737},
#  {'signals': {'CrksftTqMinImCapV': 0,
#    'CrksftMaxTrqLmtV': 1,
#    'DrvIntndCrksftTrqRw': 297.5,
#    'DrvIntndCrksftTrqMin': -10.5,
#    'CrksftTqMinImCap': -5.5,
#    'DrvIntndCrksftTrq': 297.5,
#    'CrksftMaxTrqLmt': 388.5},
#   'timestamp': 40235726},
#  {'signals': {'EngTrqRdFlrSt': 0,
#    'EngTrqActExtRngV': 0,
#    'EngTrqActExtRng': 303.5,
#    'AuxHtrAlwd': 0,
#    'AccPosV': 0,
#    'EngTrqDrRqdExtRngV': 0,
#    'EngTrqDrRqdExtRng': 297.5,
#    'FuelFltRmnLf': 0.0,
#    'HillDscntCtrlSwStat': 0,
#    'HillDscntCtrlSwStatARC': 0,
#    'AccPos': 38.823543,
#    'AppCltchAutSrtIO': 0,
#    'GlwPlgCrnkDelAct': 0,
#    'HillDscntCtrlSwStatPVal': 0},
#   'timestamp': 40235728},
#  {'signals': {'BrkPdlModTrvlV': 0,
#    'BrkPdlModTrvl': 0,
#    'BrkPedPosAlvRolngCnt': 0,
#    'BrkPdlInTrvPrt': 0,
#    'BrkPedTrvlAchvd': 0,
#    'BrkPedTrvlAchvdV': 0,
#    'BrkPdlPos': 1.568628,
#    'BrkPdlPosGrad': 0,
#    'BrkAppSnsrHmPosLrnd': 1,
#    'NotEventStat': 0,
#    'BrkPdlChkData': 28561},
#   'timestamp': 40236755},
#  {'signals': {'WRSLDWhlDisTpRC': 0,
#    'WRSLDSeqNum': 0,
#    'WRSLDWhlRotStatRst': 0,
#    'WRSLDWhlDistVal': 0,
#    'WRSLDWhlDistPlsCntr': 342,
#    'WRSLDWhlDistTmstm': 53373,
#    'WRSRDWhlDisTpRC': 0,
#    'WRSRDSeqNum': 0,
#    'WRSRDWhlRotStatRst': 0,
#    'WRSRDWhlDistVal': 0,
#    'WRSRDWhlDistPlsCntr': 591,
#    'WRSRDWhlDistTmstm': 26997},
#   'timestamp': 40237742},
#  {'signals': {'WRSLNDWhlDisTpRC': 0,
#    'WRSLNDSeqNum': 0,
#    'WRSLNDWhlRotStRst': 0,
#    'WRSLNDWhlDistVal': 0,
#    'WRSLNDWhlDistPCntr': 635,
#    'WRSLNDWhlDistTstm': 6349,
#    'WRSRNDWhlDisTpRC': 0,
#    'WRSRNDSeqNum': 0,
#    'WRSRNDWhlRotStRst': 0,
#    'WRSRNDWhlDistVal': 0,
#    'WRSRNDWhlDistPCntr': 391,
#    'WRSRNDWhlDistTstm': 60505},
#   'timestamp': 40237744},
#  {'signals': {'LKATrqOvrlTrqDStat': 0,
#    'LKAElPwrStTtlTqDlvd': 0.0,
#    'HndsOffStrWhlDtStV': 0,
#    'HndsOffStrWhlDtSt': 0,
#    'HndsOffStrWhlDtMd': 0,
#    'LKATrqOvrlDltTrqDlvd': 0.0,
#    'LKATrqOvrlDlvdRC': 0,
#    'LKATrqOvrlStatChksm': 0,
#    'LKADrvAppldTrqV': 1,
#    'LKADrvAppldTrq': -0.01},
#   'timestamp': 40237745},
#  {'signals': {'APAEngTrqRdctnAct': 0,
#    'CSETRER_TqIntvnTyp': 0,
#    'CSETRER_TorqReqVal': 1199.5,
#    'TCAliveRC': 0,
#    'ChsSysEngTrqReqProt': 12289,
#    'TracCntrlMaxTorqIncRt': 1008},
#   'timestamp': 40237747},
#  {'signals': {'aaa': 9799560108119818239}, 'timestamp': 40237748},
#  {'signals': {'StrWhAngV': 0,
#    'StrWhlAngSenCalStat': 2,
#    'StrWhlAngSenTyp': 0,
#    'StrWhAngMsk': 1,
#    'StrWhAng': -5.1875,
#    'StrWhAngGrdV': 1,
#    'StWhlAngAliveRollCnt': 1,
#    'StrWhAngGrdMsk': 0,
#    'StrWhAngGrd': 0,
#    'StrAngSnsChksm': 512},
#   'timestamp': 40238752},
#  {'signals': {'BrkPdlDrvAppPrsDetcdV': 0,
#    'BrkPdlDrvAppPrsDetcd': 0,
#    'TrnsBrkSysCltchRelRqd': 0,
#    'VSELatAccV': 0,
#    'VSELatAcc': 0.65625,
#    'BSTGRReqType': 0,
#    'BSTGRReqdGear': 0,
#    'ACCBrkngAct': 0,
#    'ABSAtv': 0,
#    'ABSFld': 0,
#    'TCSysAtv': 0,
#    'TCSysEnbld': 1,
#    'TracCntrlSysDrIntnt': 1,
#    'IMUDataMsk': 0,
#    'VSEAct': 0,
#    'VhDynCntlSysSt': 0,
#    'VehDynYawRateV': 0,
#    'VehDynYawRate': -0.75,
#    'DrvIndpntBrkAppAct': 0,
#    'EnhDrvMdSwChUseRq': 0,
#    'WhlSlpSt': 0,
#    'VehDynOvrUndrStrV': 0,
#    'VehDynOvrUndrStr': 0.0},
#   'timestamp': 40238754},
#  {'signals': {'aaa': 186296078303231}, 'timestamp': 40238756},
#  {'signals': {'CrsCntrlSwStCanSwAct': 0,
#    'CrsCntrlSwStOnSwAct': 1,
#    'CrsCntrlSwStResSwAct': 0,
#    'CrsCntrlSwStSetSwAct': 0,
#    'CrsCntrlSwStSpdInSwAct': 0,
#    'CrsCntrlSwStSpDcSwAct': 0,
#    'CrsCntrlSwStSwDataIntgty': 0,
#    'CrsCntrlSwStatProtValue': 192,
#    'AdptCrsGapSwAct': 0,
#    'CrsCntCncRq': 0,
#    'CrsCntrlSwStAlvRollCnt': 0,
#    'AuxHtrRq': 0,
#    'AuxHtrAtv': 0,
#    'FuelMdSwActV': 0,
#    'FuelMdSwAct': 0,
#    'CrsSecSwStat': 0,
#    'DrvSelMdSw1Sta': 0,
#    'DrvSelMdSw2Sta': 0,
#    'DrvSelMdSw3Sta': 0,
#    'DrvSelMdSwStaARC': 0,
#    'CrsSpdLmtrSwStat': 9,
#    'CrsSpdLmtrSwStatARC': 0,
#    'CrsSecSwStatARC': 1,
#    'CrsSpdLmtrSwStatPVal': 15,
#    'CrsSecSwStatPVal': 15},
#   'timestamp': 40238757},
#  {'signals': {'TrnsAliveRC': 3,
#    'TESR_EngSpdIntTyp': 0,
#    'TESR_EngSpdCntlRsp': 0,
#    'TESR_EngSpdRqVal': 0,
#    'TrnsCyDactTransStat': 0,
#    'TrnsEngSpdRqProt': 16381,
#    'TransNtrlCntrlMdStat': 0,
#    'TrnTrbAngVlV': 0,
#    'TrnGrRatV': 0,
#    'EngBrkDsblReqd': 0,
#    'TrnPrfAlgShfAtv': 0,
#    'TrnsRtoCntlSysFlt': 0,
#    'TrnsGrgShftAct': 0,
#    'TrnTrbAngVl': 2012.5,
#    'TrnGrRat': 0.96875},
#   'timestamp': 40241985},
#  {'signals': {'TrnsAntcptdCrpTrqRRnV': 0,
#    'TDslPrtFltrIdlRgtnMdAtv': 0,
#    'TransCrnkPermsnStat': 0,
#    'WrmUpShftPtrn': 0,
#    'TrnCltAdpAtv': 0,
#    'TrnsInpCltchStat': 0,
#    'TrnsAntcptdCrpTrqRRn': 0.0,
#    'TransCrnkPermsnStatV': 0,
#    'TrnsTrqCnvCltCmndMd': 2,
#    'TrnsTrqCnvCltCmdMdF': 0,
#    'AutoTransGrSftDirect': 0,
#    'AutoTransGrSftDirectFl': 0,
#    'TrnsStEconMdOvrd': 0,
#    'TrnsStSprtMdOvrd': 1,
#    'TrnsStTwHaulMdOvrd': 1,
#    'TrnsStWntrMdOvrd': 1,
#    'TrnsInpCltchStatV': 0,
#    'DrvlneTrqStabStat': 0,
#    'TrnsTrqCnvCltDsrSlp': 113,
#    'TransMinVoltReq': 0.0,
#    'TransVehTopSpdLim': 510},
#   'timestamp': 40242998},
#  {'signals': {'TrnsTrqCnvCltCmndMd': 2,
#    'TransEstGearV': 0,
#    'TransEstGear': 5,
#    'TopTrvlCltchSwActV': 0,
#    'TopTrvlCltchSwAct': 0,
#    'AutoTransGrSftDirect': 0,
#    'AutoTransComndGear': 5,
#    'TrnsSkpShftIO': 0,
#    'EngRecmndUpshftIO': 0,
#    'DrShftCntrlReqDndIO': 0,
#    'DrvtShftCntrlTrgtGear': 0,
#    'TrnsRngInhbtStat': 0,
#    'TrnsShftLvrPosV': 0,
#    'TrnsShftLvrPos': 4,
#    'ElcRngSelDrvAct': 0,
#    'CltStartSwAtvV': 0,
#    'CltStartSwAtv': 0,
#    'TrnsSftMdStat': 0,
#    'TrnsShftLvrLckRqd': 0,
#    'TrnCrpMdAtv': 0,
#    'TmpDrvrShftCtlAct': 0,
#    'TrnShftPtrnActStat': 0,
#    'TransTUDMdStat': 0,
#    'CltchPdlActPosV': 0,
#    'EngRecDwnshftIO': 0,
#    'PropSysBrkLitsReqd': 0,
#    'TrnsPattSelEcnMdOCm': 0,
#    'TrnsFldPrsPrsnt': 1,
#    'TrnsEngdStateV': 0,
#    'TrnsEngdState': 1,
#    'CltchPdlActPos': 0.0},
#   'timestamp': 40242999},
#  {'signals': {'PTSnsdBrkPdlInfARC': 0,
#    'TrnsAuxPmpAct': 0,
#    'PSBPI_PTSnBrkPdlPsV': 0,
#    'PSBPI_PTSnBrkPdlPs': 1.960785,
#    'AccPos': 39.2157,
#    'EngSpdMaxCapRdcdRng': 7608,
#    'PTSnsdBrkPdlInfPVal': 401},
#   'timestamp': 40245304},
#  {'signals': {'EngRunAtv': 1,
#    'PT_CrnkAct': 0,
#    'PTCrnkAbrted': 0,
#    'PTRunAbrt': 0,
#    'PTO_PT_RunAbrtd': 0,
#    'EngIdlAtv': 0,
#    'EngSpdStat': 0,
#    'EngSpd': 2106.0,
#    'AccActPosV': 0,
#    'CrsCntAtv': 0,
#    'CrsCntEnbld': 1,
#    'DrvThrottlOvrrdDet': 0,
#    'DrThrtlOvrdDetAlvRlCnt': 0,
#    'DrThrtlOvrrdDetProtVal': 0,
#    'AccActPos': 38.823543,
#    'SpdLmtrSpdWrngEnbld': 0,
#    'PFEngSpdCmndSpcd': 0,
#    'PltfrmEngSpdCmdInhtRq': 0,
#    'EngCylDeactMd': 0,
#    'PT_BrkPedDscrtInpStatV': 0,
#    'PT_BrkPedDscrtInpStat': 0,
#    'RmVhStrtEngRng': 0,
#    'EngCylDactEvntPndg': 0,
#    'Eng12vStrtrMtrCmmdOn': 0,
#    'EngCntrlRunCrnkTrmSt': 1,
#    'EngAirIntBstPrV': 1,
#    'EngAirIntBstPr': 0},
#   'timestamp': 40246296},
#  {'signals': {'PTACCAct': 0,
#    'TrnsEngSpdReqFld': 0,
#    'EngPrdctTrqTnsRqLmS': 0,
#    'EngPrdctTrqTnsRqStat': 0,
#    'EngActStdyStTorqV': 0,
#    'AccKdwnAtv': 0,
#    'EngImmTrqTnsRqLmSt': 0,
#    'EngImmTrqTnsRqStat': 0,
#    'EngNTrnsRegStdyStTqV': 0,
#    'CTSS_StbltyTyp': 0,
#    'CTSS_StbltyLvl': 0,
#    'EngActStdyStTorq': 301.5,
#    'EngNTrnsRegStdyStTq': 301.5,
#    'CrksftNTrnsRegCmdTq': 297.5},
#   'timestamp': 40246298},
#  {'signals': {'BrkPdlModTrvlV': 0,
#    'BrkPdlModTrvl': 0,
#    'BrkPedPosAlvRolngCnt': 1,
#    'BrkPdlInTrvPrt': 3,
#    'BrkPedTrvlAchvd': 0,
#    'BrkPedTrvlAchvdV': 0,
#    'BrkPdlPos': 1.568628,
#    'BrkPdlPosGrad': 0,
#    'BrkAppSnsrHmPosLrnd': 1,
#    'NotEventStat': 0,
#    'BrkPdlChkData': 28561},
#   'timestamp': 40246300},
#  {'signals': {'TORSRotDir': 0,
#    'TORSLstTransType': 0,
#    'TORSRstOcrd': 0,
#    'TORSValidity': 0,
#    'TORSPulsCntr': 986,
#    'TORSTimestamp': 18365},
#   'timestamp': 40246301},
#  {'signals': {'FuelCntlSysFltPrsnt': 0,
#    'FlPmpEDscOtptCmdSta': 1,
#    'EngRunng': 1,
#    'FuelDelPressRqd': 400,
#    'InstFuelFlowEst': 3.9648417200000003,
#    'HiPresFuelPmpCntMd': 2,
#    'HiPresFuelPmpDelDur': 67,
#    'CmmndAirFuelRatio': 14.680168265},
#   'timestamp': 40247304},
#  {'signals': {'TrnsOvrallEstTorqRatioV': 0,
#    'TrnsOvrallEstTorqRatio': 1.0,
#    'TrnsOutShftAngVelV': 0,
#    'TrnsOtptShftAngVelSnrPr': 1,
#    'TrnsOtptRotRCRstOcc': 0,
#    'TrnsOtptRotRCV': 0,
#    'TrnsRqHSABrkPrDcyRt': 0,
#    'TrnsDrvlneTqShpDisRq': 0,
#    'TrnsOutShftAngVel': 636.75,
#    'TrnsOtptRotRC': 451.0546875,
#    'TransDsrdTrqRatio': 0.5304},
#   'timestamp': 40247305},
#  {'signals': {'TrnsTrqRqALC': 1,
#    'TIDCTR_TrqRespTyp': 0,
#    'TIDCTR_TrqReqVal': 1199.5,
#    'TIDCTR_TrqIntvTyp': 0,
#    'TPCTR_TrqIntrvnTyp': 0,
#    'TPCTR_TorqReqVal': 1199.5,
#    'TrnsPdCrkshftTqRqPVa': 12288,
#    'TrnsTrqCap': 1020},
#   'timestamp': 40247307},
#  {'signals': {'WRSLDWhlDisTpRC': 0,
#    'WRSLDSeqNum': 1,
#    'WRSLDWhlRotStatRst': 0,
#    'WRSLDWhlDistVal': 0,
#    'WRSLDWhlDistPlsCntr': 347,
#    'WRSLDWhlDistTmstm': 55999,
#    'WRSRDWhlDisTpRC': 0,
#    'WRSRDSeqNum': 1,
#    'WRSRDWhlRotStatRst': 0,
#    'WRSRDWhlDistVal': 0,
#    'WRSRDWhlDistPlsCntr': 596,
#    'WRSRDWhlDistTmstm': 29626},
#   'timestamp': 40247308},
#  {'signals': {'WRSLNDWhlDisTpRC': 0,
#    'WRSLNDSeqNum': 1,
#    'WRSLNDWhlRotStRst': 0,
#    'WRSLNDWhlDistVal': 0,
#    'WRSLNDWhlDistPCntr': 640,
#    'WRSLNDWhlDistTstm': 8990,
#    'WRSRNDWhlDisTpRC': 0,
#    'WRSRNDSeqNum': 1,
#    'WRSRNDWhlRotStRst': 0,
#    'WRSRNDWhlDistVal': 0,
#    'WRSRNDWhlDistPCntr': 396,
#    'WRSRNDWhlDistTstm': 63136},
#   'timestamp': 40247310},
#  {'signals': {'StrWhAngV': 0,
#    'StrWhlAngSenCalStat': 2,
#    'StrWhlAngSenTyp': 0,
#    'StrWhAngMsk': 1,
#    'StrWhAng': -5.1875,
#    'StrWhAngGrdV': 1,
#    'StWhlAngAliveRollCnt': 2,
#    'StrWhAngGrdMsk': 0,
#    'StrWhAngGrd': 0,
#    'StrAngSnsChksm': 256},
#   'timestamp': 40248308},
#  {'signals': {'MassAirFloV': 0, 'MassAirFlo': 62.24}, 'timestamp': 40248311},
#  {'signals': {'unknow': 1152921983220056063}, 'timestamp': 40250691},
#  {'signals': {'BrkPdlModTrvlV': 0,
#    'BrkPdlModTrvl': 0,
#    'BrkPedPosAlvRolngCnt': 2,
#    'BrkPdlInTrvPrt': 2,
#    'BrkPedTrvlAchvd': 0,
#    'BrkPedTrvlAchvdV': 0,
#    'BrkPdlPos': 1.568628,
#    'BrkPdlPosGrad': 0,
#    'BrkAppSnsrHmPosLrnd': 1,
#    'NotEventStat': 0,
#    'BrkPdlChkData': 28561},
#   'timestamp': 40256111},
#  {'signals': {'WRSLDWhlDisTpRC': 0,
#    'WRSLDSeqNum': 2,
#    'WRSLDWhlRotStatRst': 0,
#    'WRSLDWhlDistVal': 0,
#    'WRSLDWhlDistPlsCntr': 352,
#    'WRSLDWhlDistTmstm': 58628,
#    'WRSRDWhlDisTpRC': 0,
#    'WRSRDSeqNum': 2,
#    'WRSRDWhlRotStatRst': 0,
#    'WRSRDWhlDistVal': 0,
#    'WRSRDWhlDistPlsCntr': 601,
#    'WRSRDWhlDistTmstm': 32263},
#   'timestamp': 40257138},
#  {'signals': {'WRSLNDWhlDisTpRC': 0,
#    'WRSLNDSeqNum': 2,
#    'WRSLNDWhlRotStRst': 0,
#    'WRSLNDWhlDistVal': 0,
#    'WRSLNDWhlDistPCntr': 645,
#    'WRSLNDWhlDistTstm': 11636,
#    'WRSRNDWhlDisTpRC': 0,
#    'WRSRNDSeqNum': 2,
#    'WRSRNDWhlRotStRst': 0,
#    'WRSRNDWhlDistVal': 0,
#    'WRSRNDWhlDistPCntr': 401,
#    'WRSRNDWhlDistTstm': 232},
#   'timestamp': 40257141},
#  {'signals': {'LKATrqOvrlTrqDStat': 0,
#    'LKAElPwrStTtlTqDlvd': 0.01,
#    'HndsOffStrWhlDtStV': 0,
#    'HndsOffStrWhlDtSt': 0,
#    'HndsOffStrWhlDtMd': 0,
#    'LKATrqOvrlDltTrqDlvd': 0.0,
#    'LKATrqOvrlDlvdRC': 0,
#    'LKATrqOvrlStatChksm': 511,
#    'LKADrvAppldTrqV': 1,
#    'LKADrvAppldTrq': -0.01},
#   'timestamp': 40258124},
#  {'signals': {'APAEngTrqRdctnAct': 0,
#    'CSETRER_TqIntvnTyp': 0,
#    'CSETRER_TorqReqVal': 1199.5,
#    'TCAliveRC': 1,
#    'ChsSysEngTrqReqProt': 12288,
#    'TracCntrlMaxTorqIncRt': 1008},
#   'timestamp': 40258126}]

# %%
steering,yaw,speed = db.GetMostRecentOdometry(can_decoder,data1000['scala']['timeofissue'])

# %%
xyz1 = data1000['scala']['data'][:,:3]
plt.plot(-xyz1[:,1],xyz1[:,0],'.')
plt.ylim(0, 100)
plt.xlim(-20, 20)
plt.grid()

# %%
xyz1 = data1000['scala']['data'][:,:3]
xyz2 = data1001['scala']['data'][:,:3]
plt.plot(-xyz1[:,1],xyz1[:,0],'.')
plt.plot(-xyz2[:,1],xyz2[:,0]+speed/3.6*(data1001['scala']['timestamp']-data1000['scala']['timestamp'])/1000000,'.')
plt.ylim(30, 35)
plt.xlim(-5, 2)
plt.grid()

# %%
absolute_angle
# Out:
# 0

# %%
data = ApplyCalib(data,sample_number,0)

# %%
xyz1 = data[:,:3]

id = np.where( (xyz1[:,1]>-2) &  (xyz1[:,1]<2) & (xyz1[:,0]<20)& (xyz1[:,0]>2))[0]

plt.plot(xyz1[id,0],xyz1[id,2],'.')
plt.grid()

# %%
from sklearn.linear_model import RANSACRegressor
from sklearn.datasets import make_regression
from sklearn import linear_model

def remove_ground(xyz):
    
    id = np.where( (xyz1[:,1]>-5) &  (xyz1[:,1]<5) & (xyz1[:,0]<25)& (xyz1[:,0]>2))[0]
    
    
    X = xyz1[id,0].reshape((-1, 1))
    y = xyz1[id,2]
    lr = linear_model.RANSACRegressor()
    lr.fit(X,y)
    id = np.where( (xyz[:,2] > 0.1+(xyz[:,0] * lr.estimator_.coef_[0])))[0]
    
    return xyz[id,:]

# %%
xyz2 = remove_ground(xyz1)

plt.plot(-xyz1[:,1],xyz1[:,0],'.')
plt.plot(-xyz2[:,1],xyz2[:,0],'.')
plt.grid()
plt.ylim(0, 100)
plt.xlim(-20, 20)
plt.grid()

# %%
X = xyz1[id,0].reshape((-1, 1))
y = xyz1[id,2]

# %%
from sklearn.linear_model import RANSACRegressor
from sklearn.datasets import make_regression
from sklearn import linear_model

lr = linear_model.RANSACRegressor()
lr.fit(X,y)


y_pred = lr.predict(X)
plt.plot(X,y,'.')
plt.plot(X,y_pred,'r.')
plt.grid()

# %%
lr.estimator_.coef_[0]
# Out:
# 0.0023441933876203677

# %%
id = np.where( (xyz1[:,2] > (xyz1[:,0] * lr.coef_[0])))[0]
plt.plot(-xyz1[:,1],xyz1[:,0],'.')
plt.plot(-xyz1[id,1],xyz1[id,0],'.')
plt.grid()
plt.ylim(0, 100)
plt.xlim(-20, 20)
plt.grid()

# %% [markdown]
# ### Go through the dataset

# %%
# Create an iterator on the dataset
ite = iter(db)
pcd = o3d.geometry.PointCloud()

# iterate through the entire dataset
# it replays the data with the same order it has been recorded
#it s sequential, that is to say each data will be from one of the sensor, but
# not all at the same time
for i in range(len(db)):
    timestamp,sample,sensor,data=next(ite)
    
    print('timestamp: ',timestamp,'Sensor: ',sensor,'sample: ',sample)

# %%
timestamp,sample,sensor,data=db.GetSensorData(0)
xyz = data[:,:3]

# %%
pcd.points = o3d.utility.Vector3dVector(xyz[:,:3])
o3d.visualization.draw_geometries([pcd])

# %%
sensor

# %%
'image_{:06}.png'.format(10)
# Out:
# 'image_000010.png'
